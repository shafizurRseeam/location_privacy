# %%
import numpy as np
import pandas as pd
import os

# %%
base_directory_input_O_b50_d5 = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_50_delta_5'


file_name_1_O_b50_d5 = 'merged_our_bl_50_delta_5_0.1.csv'
file_name_2_O_b50_d5 = 'merged_our_bl_50_delta_5_0.2.csv'
file_name_3_O_b50_d5 = 'merged_our_bl_50_delta_5_0.5.csv'
#file_name_4_O_b50_d5 = 'merged_our_0.7.csv'
file_name_5_O_b50_d5 = 'merged_our_bl_50_delta_5_1.csv'
file_name_6_O_b50_d5 = 'merged_our_bl_50_delta_5_2.csv'
file_name_7_O_b50_d5 = 'merged_our_bl_50_delta_5_3.csv'
file_name_8_O_b50_d5 = 'merged_our_bl_50_delta_5_4.csv'
file_name_9_O_b50_d5 = 'merged_our_bl_50_delta_5_5.csv'



file_path1_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_1_O_b50_d5)
file_path2_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_2_O_b50_d5)
file_path3_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_3_O_b50_d5)
#file_path4_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_4_O_b50_d5)
file_path5_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_5_O_b50_d5)
file_path6_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_6_O_b50_d5)
file_path7_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_7_O_b50_d5)
file_path8_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_8_O_b50_d5)
file_path9_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_9_O_b50_d5)






df1_O_b50_d5 = pd.read_csv(file_path1_O_b50_d5)
df2_O_b50_d5 = pd.read_csv(file_path2_O_b50_d5)
df3_O_b50_d5 = pd.read_csv(file_path3_O_b50_d5)
#df4_O_b50_d5 = pd.read_csv(file_path4_O_b50_d5)
df5_O_b50_d5 = pd.read_csv(file_path5_O_b50_d5)
df6_O_b50_d5 = pd.read_csv(file_path6_O_b50_d5)
df7_O_b50_d5 = pd.read_csv(file_path7_O_b50_d5)
df8_O_b50_d5 = pd.read_csv(file_path8_O_b50_d5)
df9_O_b50_d5 = pd.read_csv(file_path9_O_b50_d5)

# %%
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]
dataframes_O_b50_d5 = [df1_O_b50_d5, df2_O_b50_d5, df3_O_b50_d5, df5_O_b50_d5, df6_O_b50_d5, df7_O_b50_d5, df8_O_b50_d5, df9_O_b50_d5]
x_values_O_b50_d5 = []

for df in dataframes_O_b50_d5:
    # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
    mean_value = df['l2_distance'].mean()  # This calculates the mean across all columns and then the mean of those means
    x_values_O_b50_d5.append(mean_value)

# x_values_O_t_b50_d5 = []

# for df in dataframes_O_b50_d5:
#     # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
#     mean_value = (df['distance_x_z'].sum())/file_count  # This calculates the mean across all columns and then the mean of those means
#     x_values_O_t_b50_d5.append(mean_value)

# %%
base_directory_input_O_b50_d10 = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_50_delta_10'

file_name_1_O_b50_d10 = 'merged_our_bl_50_delta_10_0.1.csv'
file_name_2_O_b50_d10=  'merged_our_bl_50_delta_10_0.2.csv'
file_name_3_O_b50_d10 = 'merged_our_bl_50_delta_10_0.5.csv'
#file_name_4_O_b50_d10 = 'merged_our_0.7.csv'
file_name_5_O_b50_d10 = 'merged_our_bl_50_delta_10_1.csv'
file_name_6_O_b50_d10 = 'merged_our_bl_50_delta_10_2.csv'
file_name_7_O_b50_d10 = 'merged_our_bl_50_delta_10_3.csv'
file_name_8_O_b50_d10 = 'merged_our_bl_50_delta_10_4.csv'
file_name_9_O_b50_d10 = 'merged_our_bl_50_delta_10_5.csv'



file_path1_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_1_O_b50_d10 )
file_path2_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_2_O_b50_d10 )
file_path3_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_3_O_b50_d10 )
#file_path4_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_4_O_b50_d10 )
file_path5_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_5_O_b50_d10 )
file_path6_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_6_O_b50_d10 )
file_path7_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_7_O_b50_d10 )
file_path8_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_8_O_b50_d10 )
file_path9_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_9_O_b50_d10 )






df1_O_b50_d10 = pd.read_csv(file_path1_O_b50_d10)
df2_O_b50_d10 = pd.read_csv(file_path2_O_b50_d10)
df3_O_b50_d10 = pd.read_csv(file_path3_O_b50_d10)
#df4_O_b50_d10 = pd.read_csv(file_path4_O_b50_d10)
df5_O_b50_d10 = pd.read_csv(file_path5_O_b50_d10)
df6_O_b50_d10 = pd.read_csv(file_path6_O_b50_d10)
df7_O_b50_d10 = pd.read_csv(file_path7_O_b50_d10)
df8_O_b50_d10 = pd.read_csv(file_path8_O_b50_d10)
df9_O_b50_d10 = pd.read_csv(file_path9_O_b50_d10)

# %%
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]
dataframes_O_b50_d10 = [df1_O_b50_d10, df2_O_b50_d10, df3_O_b50_d10, df5_O_b50_d10, df6_O_b50_d10, df7_O_b50_d10, df8_O_b50_d10, df9_O_b50_d10]
x_values_O_b50_d10 = []

for df in dataframes_O_b50_d10:
    # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
    mean_value = df['l2_distance'].mean()  # This calculates the mean across all columns and then the mean of those means
    x_values_O_b50_d10.append(mean_value)

# x_values_O_t_b50_d10 = []

# for df in dataframes_O_b50_d10:
#     # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
#     mean_value = (df['distance_x_z'].sum())/file_count  # This calculates the mean across all columns and then the mean of those means
#     x_values_O_t_b50_d10.append(mean_value)

# %%
base_directory_input_O_b50_d20 = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_50_delta_20'



file_name_1_O_b50_d20 = 'merged_our_bl_50_delta_20_0.1.csv'
file_name_2_O_b50_d20=  'merged_our_bl_50_delta_20_0.2.csv'
file_name_3_O_b50_d20 = 'merged_our_bl_50_delta_20_0.5.csv'
#file_name_4_O_b50_d10 = 'merged_our_0.7.csv'
file_name_5_O_b50_d20 = 'merged_our_bl_50_delta_20_1.csv'
file_name_6_O_b50_d20 = 'merged_our_bl_50_delta_20_2.csv'
file_name_7_O_b50_d20 = 'merged_our_bl_50_delta_20_3.csv'
file_name_8_O_b50_d20 = 'merged_our_bl_50_delta_20_4.csv'
file_name_9_O_b50_d20 = 'merged_our_bl_50_delta_20_5.csv'



file_path1_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_1_O_b50_d20 )
file_path2_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_2_O_b50_d20 )
file_path3_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_3_O_b50_d20 )
#file_path4_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_4_O_b50_d10 )
file_path5_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_5_O_b50_d20 )
file_path6_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_6_O_b50_d20 )
file_path7_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_7_O_b50_d20 )
file_path8_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_8_O_b50_d20 )
file_path9_O_b50_d20 = os.path.join(base_directory_input_O_b50_d20, file_name_9_O_b50_d20 )






df1_O_b50_d20 = pd.read_csv(file_path1_O_b50_d20)
df2_O_b50_d20 = pd.read_csv(file_path2_O_b50_d20)
df3_O_b50_d20 = pd.read_csv(file_path3_O_b50_d20)
#df4_O_b50_d10 = pd.read_csv(file_path4_O_b50_d10)
df5_O_b50_d20 = pd.read_csv(file_path5_O_b50_d20)
df6_O_b50_d20 = pd.read_csv(file_path6_O_b50_d20)
df7_O_b50_d20 = pd.read_csv(file_path7_O_b50_d20)
df8_O_b50_d20 = pd.read_csv(file_path8_O_b50_d20)
df9_O_b50_d20 = pd.read_csv(file_path9_O_b50_d20)

# %%
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]
dataframes_O_b50_d20 = [df1_O_b50_d20, df2_O_b50_d20, df3_O_b50_d20, df5_O_b50_d20, df6_O_b50_d20, df7_O_b50_d20, df8_O_b50_d20, df9_O_b50_d20]
x_values_O_b50_d20 = []

for df in dataframes_O_b50_d20:
    # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
    mean_value = df['l2_distance'].mean()  # This calculates the mean across all columns and then the mean of those means
    x_values_O_b50_d20.append(mean_value)

# x_values_O_t_b50_d20 = []

# for df in dataframes_O_b50_d20:
#     # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
#     mean_value = (df['distance_x_z'].sum())/file_count  # This calculates the mean across all columns and then the mean of those means
#     x_values_O_t_b50_d20.append(mean

# %%
x_O_b50_d5=[x_values_O_b50_d5[0], x_values_O_b50_d5[3], x_values_O_b50_d5[7]]
x_O_b50_d10=[x_values_O_b50_d10[0], x_values_O_b50_d10[3], x_values_O_b50_d10[7]]
x_O_b50_d20=[x_values_O_b50_d20[0], x_values_O_b50_d20[3], x_values_O_b50_d20[7]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your data
epsilon_values = [0.1,  1,  5]
deltas = [5, 10, 20]

l2_distances_delta_5 = x_O_b50_d5  # Replace with your actual data
l2_distances_delta_10 = x_O_b50_d10  # Replace with your actual data
l2_distances_delta_20 = x_O_b50_d20  # Replace with your actual data
l2_distances = [l2_distances_delta_5, l2_distances_delta_10, l2_distances_delta_20]

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Light color theme
colors = ['lightblue', 'lightgreen', 'lightcoral']
patterns = ['/', '\\', '|']

# Bar setup
width = 0.2
n_bars = len(l2_distances_delta_5)
delta_gap = 0.1
group_width = n_bars * width + delta_gap
x = np.arange(len(deltas)) * group_width

# Plotting bars with light colors and hatch patterns
for delta_index, delta in enumerate(deltas):
    for bar_index in range(n_bars):
        bar_position = x[delta_index] + bar_index * width
        bar_height = l2_distances[delta_index][bar_index]
        ax.bar(bar_position, bar_height, width,
               color=colors[delta_index], edgecolor='black',
               hatch=patterns[bar_index] * 3, alpha=0.7)
        ax.text(bar_position, bar_height, f'$\epsilon$ = {epsilon_values[bar_index]}', 
                ha='center', va='bottom', fontsize=16)

# Customization of the plot
ax.set_xlabel('$\delta$', fontsize=20)
ax.set_ylabel('Average $L_2$-Distance', fontsize=20)
ax.set_xticks(x + width * (n_bars - 1) / 2)
ax.set_xticklabels(deltas)
plt.tick_params(axis='both', which='major', labelsize=20)

# Customizing the grid
ax.grid(True, linestyle='-', alpha=0.3)  # Major grid with solid lines
ax.minorticks_on()  # Enable minor ticks
ax.grid(which='minor', linestyle=':', alpha=0.2)  # Minor grid with dotted lines

plt.tight_layout()

# Saving the plot as a high-definition PNG

#pathpng = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\png\\Geolife_DeltaEffect'
#plt.savefig(pathpng, dpi=300, bbox_inches='tight')

# Saving the plot as an SVG
#pathsvg = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\svg\\Geolife_DeltaEffect'
#plt.savefig(pathsvg, format='svg', bbox_inches='tight')

# Show the plot
plt.tight_layout()
plt.show()
