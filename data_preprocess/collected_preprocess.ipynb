# %%
import os
import pandas as pd
import shutil
from dateutil.parser import parse
import glob

# %%
import os

# Replace these paths with your actual directory paths
source_directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_location-main\\dataset_location-main'
destination_directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Ensure the destination directory exists
os.makedirs(destination_directory_path, exist_ok=True)

# Walk through the source directory
for root, dirs, files in os.walk(source_directory_path):
    # Check if we're inside the Speed_data directory, but not directly in it
    if 'Speed_data' in root and root.strip('\\').endswith('Speed_data'):
        # Only process files in Speed_data, do not go into its subdirectories
        dirs[:] = []  # This clears the dirs list in-place, preventing os.walk from going into any subdirectories
    for file in files:
        if file.endswith(".csv"):
            # Construct the original full path of the file
            original_file_path = os.path.join(root, file)
            # Extract the subdirectory name
            subdirectory_name = os.path.basename(os.path.normpath(root))
            # Construct the new file name and path
            new_file_name = f"{subdirectory_name}_{file}"
            destination_file_path = os.path.join(destination_directory_path, new_file_name)
            # Copy the file
            shutil.copy(original_file_path, destination_file_path)

print("CSV files have been copied and renamed successfully.")

# %%
import os
import pandas as pd

# Replace this path with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            # Load the CSV file
            df = pd.read_csv(file_path)
            # Check if the number of columns is not exactly 17
            if df.shape[1] != 17:
                os.remove(file_path)
                print(f"Deleted: {file_name}")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete.")

# %%
import os
import pandas as pd

# Replace this with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Replace these with your desired column names
column_names = ['deviceID', 'date', 'longitude', 'latitude', 'altitude', 'accelerometer x'
                , 'accelerometer y', 'accelerometer z', 'userAccelerometer x', 'userAccelerometer y'
                , 'userAccelerometer z', 'gyroscope x', 'gyroscope y', 'gyroscope z', 'magnetometer x', 'magnetometer y', 'magnetometer z'
]

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            # Read the CSV file without header
            df = pd.read_csv(file_path, header=None)
            # Assign the column names
            df.columns = column_names
            # Save the file back
            df.to_csv(file_path, index=False)
            print(f"Processed: {file_name}")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete.")

# %%
import os
import pandas as pd

# Replace this with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Names of the latitude and longitude columns
latitude_column_name = 'latitude'
longitude_column_name = 'longitude'

# Check if a value is within the latitude range
def is_valid_latitude(lat):
    return -90 <= lat <= 90

# Check if a value is within the longitude range
def is_valid_longitude(lon):
    return -180 <= lon <= 180

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            df = pd.read_csv(file_path)
            
            # Check if latitude and longitude columns exist
            if latitude_column_name in df.columns and longitude_column_name in df.columns:
                # Apply validity checks
                invalid_latitudes = df[~df[latitude_column_name].apply(is_valid_latitude)]
                invalid_longitudes = df[~df[longitude_column_name].apply(is_valid_longitude)]
                
                # Report findings
                if not invalid_latitudes.empty or not invalid_longitudes.empty:
                    print(f"File '{file_name}' contains invalid latitude or longitude values:")
                    if not invalid_latitudes.empty:
                        print(f"Invalid latitudes:\n{invalid_latitudes[[latitude_column_name]]}")
                    if not invalid_longitudes.empty:
                        print(f"Invalid longitudes:\n{invalid_longitudes[[longitude_column_name]]}")
                else:
                    print(f"File '{file_name}' has all valid latitude and longitude values.")
            else:
                print(f"File '{file_name}' does not contain the specified latitude and longitude columns.")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete.")

# %%
import os
import pandas as pd

# Replace this with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Names of the latitude and longitude columns
latitude_column_name = 'latitude'
longitude_column_name = 'longitude'

# Check if a value is within the latitude range
def is_valid_latitude(lat):
    return -90 <= lat <= 90

# Check if a value is within the longitude range
def is_valid_longitude(lon):
    return -180 <= lon <= 180

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            df = pd.read_csv(file_path)
            
            # Check if latitude and longitude columns exist
            if latitude_column_name in df.columns and longitude_column_name in df.columns:
                # Apply validity checks
                invalid_latitudes = df[~df[latitude_column_name].apply(is_valid_latitude)]
                invalid_longitudes = df[~df[longitude_column_name].apply(is_valid_longitude)]
                
                # If there are any invalid values, delete the file
                if not invalid_latitudes.empty or not invalid_longitudes.empty:
                    os.remove(file_path)
                    print(f"Deleted '{file_name}' due to invalid latitude or longitude values.")
            else:
                print(f"File '{file_name}' does not contain the specified latitude and longitude columns.")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete. Invalid files have been deleted.")

# %%
import os
import pandas as pd

# Replace this with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# List the names of the columns you want to keep
important_columns = ['date', 'longitude', 'latitude']

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            # Read the CSV file
            df = pd.read_csv(file_path)
            
            # Keep only the important columns, if they exist in the dataframe
            df_filtered = df[important_columns] if all(col in df for col in important_columns) else df
            
            # Save the filtered dataframe back to the same file, overwriting the original
            df_filtered.to_csv(file_path, index=False)
            print(f"Processed and saved: {file_name}")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete. Files have been overwritten with only important columns.")

# %%
import os
import pandas as pd

# Replace this with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Names of the latitude and longitude columns
latitude_column_name = 'latitude'
longitude_column_name = 'longitude'

# Function to check for NaN values or zeros
def has_invalid_values(series):
    return series.isnull().any() or (series == 0).any()

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            df = pd.read_csv(file_path)
            
            # Check if latitude and longitude columns exist
            if latitude_column_name in df and longitude_column_name in df:
                # Check for NaN values or zeros in both columns
                invalid_latitudes = has_invalid_values(df[latitude_column_name])
                invalid_longitudes = has_invalid_values(df[longitude_column_name])
                
                if invalid_latitudes or invalid_longitudes:
                    print(f"File '{file_name}' contains NaN or zero values:")
                    if invalid_latitudes:
                        print(f" - Invalid values in latitude column")
                    if invalid_longitudes:
                        print(f" - Invalid values in longitude column")
                else:
                    print(f"File '{file_name}' has valid latitude and longitude values.")
            else:
                print(f"File '{file_name}' does not contain the specified latitude and longitude columns.")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete.")

# %%
import os
import pandas as pd

# Replace this with the path to your directory
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# Names of the latitude and longitude columns
latitude_column_name = 'latitude'
longitude_column_name = 'longitude'

# Function to check for NaN values or zeros
def has_invalid_values(series):
    return series.isnull().any() or (series == 0).any()

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith(".csv"):
        file_path = os.path.join(directory_path, file_name)
        try:
            df = pd.read_csv(file_path)
            
            # Check if latitude and longitude columns exist
            if latitude_column_name in df and longitude_column_name in df:
                # Check for NaN values or zeros in both columns
                invalid_latitudes = has_invalid_values(df[latitude_column_name])
                invalid_longitudes = has_invalid_values(df[longitude_column_name])
                
                if invalid_latitudes or invalid_longitudes:
                    # Delete the file
                    os.remove(file_path)
                    print(f"Deleted '{file_name}' due to invalid latitude or longitude values.")
            else:
                print(f"File '{file_name}' does not contain the specified latitude and longitude columns.")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")

print("Processing complete. Invalid files have been deleted.")

# %%
# import os
# import pandas as pd

# # Replace this with the path to your directory
# directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\test'

# # Names of the latitude and longitude columns
# latitude_column_name = 'latitude'
# longitude_column_name = 'longitude'

# # Function to remove consecutive duplicates
# def remove_consecutive_duplicates(df, column_name):
#     # Identify rows where the value in the specified column is equal to that in the next row
#     duplicates = df[column_name].eq(df[column_name].shift())
#     # Keep rows where there is no such duplication
#     return df[~duplicates]

# # Iterate over each file in the directory
# for file_name in os.listdir(directory_path):
#     if file_name.endswith(".csv"):
#         file_path = os.path.join(directory_path, file_name)
#         try:
#             df = pd.read_csv(file_path)
            
#             # Ensure both specified columns exist
#             if latitude_column_name in df.columns and longitude_column_name in df.columns:
#                 # Remove consecutive duplicates for latitude and longitude
#                 df = remove_consecutive_duplicates(df, latitude_column_name)
#                 df = remove_consecutive_duplicates(df, longitude_column_name)
                
#                 # Save the modified DataFrame back to the CSV, overwriting the original
#                 df.to_csv(file_path, index=False)
#                 print(f"Processed and updated: {file_name}")
#             else:
#                 print(f"File '{file_name}' does not contain the specified latitude and longitude columns.")
#         except Exception as e:
#             print(f"Error processing {file_name}: {e}")

# print("Processing complete. Consecutive duplicate rows have been removed.")

# %%
import os
import pandas as pd
from dateutil.parser import parse

def infer_date_format(date_str):
    try:
        parsed_date = parse(date_str, fuzzy=True)
        return parsed_date.strftime('%Y-%m-%d %H:%M:%S')
    except ValueError:
        return None

# Specify the directory containing your CSV files
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed_remove_duplicate_rows'

# Initialize a dictionary to store inferred date formats
date_formats = {}

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(directory_path, file_name)
        
        # Attempt to load the CSV file
        try:
            df = pd.read_csv(file_path)

            # Assuming 'date' is the column name. Adjust as necessary.
            if 'date' in df.columns:
                # Find the first non-null value in the date column
                first_date_str = df['date'].dropna().iloc[0]
                # Infer the date format
                inferred_format = infer_date_format(first_date_str)
                date_formats[file_name] = inferred_format
            else:
                date_formats[file_name] = 'Date column not found'
        except Exception as e:
            date_formats[file_name] = f'Error reading file: {e}'

# Print the inferred date formats for each file
for file_name, date_format in date_formats.items():
    print(f"{file_name}: {date_format}")

# %%
import pandas as pd
import os
import numpy as np
from datetime import timedelta

def correct_24_hour_time(date_str):
    # Check if the time starts with "24"
    if date_str[-8:-6] == "24":
        # Replace "24" with "00"
        corrected_str = date_str[:-8] + "00" + date_str[-6:]
        # Convert to datetime
        corrected_datetime = pd.to_datetime(corrected_str)
        # Add a day to the date
        corrected_datetime += timedelta(days=1)
        return corrected_datetime
    else:
        # If there's no "24" hour, just convert to datetime
        return pd.to_datetime(date_str)

# Specify the directory containing your CSV files
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed_remove_duplicate_rows_without_flights'

# Initialize a list to store the results
average_intervals = []

# Sum of all average intervals
total_average_interval = 0

# Count of files processed for the overall average calculation
file_count = 0

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(directory_path, file_name)
        
        # Load the CSV file
        df = pd.read_csv(file_path)
        
        if 'date' in df.columns:
            # Apply the correction for the "24:00:XX" case and convert to datetime
            df['date'] = df['date'].apply(correct_24_hour_time)
            
            # Ensure the data is sorted by 'date'
            df = df.sort_values(by='date')
            
            # Calculate differences (intervals) between each timestamp
            df['sampling_interval_seconds'] = df['date'].diff().dt.total_seconds()
            
            # Ignore NaN values for the average calculation
            valid_intervals = df['sampling_interval_seconds'].dropna()
            
            if not valid_intervals.empty:
                average_sampling_interval = valid_intervals.mean()
                average_intervals.append((file_name, average_sampling_interval))
                total_average_interval += average_sampling_interval
                file_count += 1
            else:
                average_intervals.append((file_name, 'Insufficient data for interval calculation'))

overall_average_interval = total_average_interval / file_count if file_count > 0 else 'No valid data found in any file'

for file_name, interval in average_intervals:
    print(f"{file_name}: {interval} seconds")

print(f"\nOverall average sampling interval across all files: {overall_average_interval} seconds")
# Out:
# Hu_Samsung_S22_csv-1706551395849.csv: 1.2313019390581716 seconds
# Hu_Samsung_S22_csv-1706554333642.csv: 1.8215527230590962 seconds
# Hu_Samsung_S22_csv-1706556488903.csv: 2.0304373522458627 seconds
# Hu_Samsung_S22_csv-1706629866070.csv: 14.495664739884393 seconds
# Hu_Samsung_S22_csv-1706645959366.csv: 15.088645262333594 seconds
# Hu_Samsung_S22_csv-1706648412755.csv: 13.77317719224871 seconds
# Hu_Samsung_S22_csv-1706719083524.csv: 19.207185764479203 seconds
# Hu_Samsung_S22_csv-1707167485257.csv: 0.7369337979094077 seconds
# Hu_Samsung_S22_csv-1707168946553.csv: 1.4846335697399526 seconds
# Hu_Samsung_S22_csv-1707169047177.csv: 1.3952180028129395 seconds
# Hu_Samsung_S22_csv-1707169378518.csv: 4.142857142857143 seconds
# Hu_Samsung_S22_csv-1707169583100.csv: 1.7659425367904695 seconds
# Hu_Samsung_S22_csv-1707171684371.csv: 43.113207547169814 seconds
# Hu_Samsung_S22_csv-1707183508643.csv: 0.8452173913043478 seconds
# Hu_Samsung_S22_csv-1707228280586.csv: 54.99149453219927 seconds
# Hu_Samsung_S22_csv-1707229230038.csv: 31.977162629757785 seconds
# Hu_Samsung_S22_csv-1707229310624.csv: 30.313032089063523 seconds
# Hu_Samsung_S22_csv-1707234256736.csv: 13.013208026416052 seconds
# Hu_Samsung_S22_csv-1707235198679.csv: 11.027689706193193 seconds
# Hu_Samsung_S22_csv-1707255641182.csv: 10.72772935440981 seconds
# Hu_Samsung_S22_csv-1710938965685.csv: 1.3929446349828516 seconds
# Hu_Samsung_S22_csv-1710974613701.csv: 10.736680613668062 seconds
# Hu_Samsung_S22_csv-1711459298652.csv: 1.0186335403726707 seconds
# Hu_Samsung_S22_csv-1711464703251.csv: 5.1574150787075395 seconds
# Hu_Samsung_S22_csv-1711464859692.csv: 5.1574150787075395 seconds
# Hu_Samsung_S22_csv-1711495663127.csv: 13.628724216959512 seconds
# Hu_Samsung_S22_csv-1711503190470.csv: 1.0344827586206897 seconds
# Hu_Samsung_S22_csv-1711503261620.csv: 2.8055555555555554 seconds
# Hu_Samsung_S22_csv-1711561058750.csv: 0.7910014513788098 seconds
# Hu_Samsung_S22_csv-1711561852741.csv: 2.652173913043478 seconds
# Li_Samsung_S10_csv-1674595237096.csv: 2.914230019493177 seconds
# Li_Samsung_S21_csv-1669614843214.csv: 6.55 seconds
# Li_Samsung_S21_csv-1671507198416.csv: 3.727272727272727 seconds
# Li_Samsung_S21_csv-1671515190653.csv: 4.80897583429229 seconds
# Li_Samsung_S21_csv-1673744211840.csv: 4.384937238493724 seconds
# Li_Samsung_S21_csv-1673887278434.csv: 77.83234042553191 seconds
# Li_Samsung_S21_csv-1674120305812.csv: 6.367306155075939 seconds
# Li_Samsung_S21_csv-1674201551799.csv: 48.623313545601725 seconds
#
# Overall average sampling interval across all files: 8.207019569154292 seconds

# %%
import pandas as pd
import os
import numpy as np
from datetime import timedelta

def correct_24_hour_time(date_str):
    # Check if the time starts with "24"
    if date_str[-8:-6] == "24":
        # Replace "24" with "00"
        corrected_str = date_str[:-8] + "00" + date_str[-6:]
        # Convert to datetime
        corrected_datetime = pd.to_datetime(corrected_str)
        # Add a day to the date
        corrected_datetime += timedelta(days=1)
        return corrected_datetime
    else:
        # If there's no "24" hour, just convert to datetime
        return pd.to_datetime(date_str)

# Specify the directory containing your CSV files
directory_path = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed_remove_duplicate_rows'

# Initialize a list to store the results
average_intervals = []

# Sum of all average intervals
total_average_interval = 0

# Count of files processed for the overall average calculation
file_count = 0

# Iterate over each file in the directory
for file_name in os.listdir(directory_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(directory_path, file_name)
        
        # Load the CSV file
        df = pd.read_csv(file_path)
        
        if 'date' in df.columns:
            # Apply the correction for the "24:00:XX" case and convert to datetime
            df['date'] = df['date'].apply(correct_24_hour_time)
            
            # Ensure the data is sorted by 'date'
            df = df.sort_values(by='date')
            
            # Calculate differences (intervals) between each timestamp
            df['sampling_interval_seconds'] = df['date'].diff().dt.total_seconds()
            
            # Ignore NaN values for the average calculation
            valid_intervals = df['sampling_interval_seconds'].dropna()
            
            if not valid_intervals.empty:
                average_sampling_interval = valid_intervals.mean()
                average_intervals.append((file_name, average_sampling_interval))
                total_average_interval += average_sampling_interval
                file_count += 1
            else:
                average_intervals.append((file_name, 'Insufficient data for interval calculation'))

overall_average_interval = total_average_interval / file_count if file_count > 0 else 'No valid data found in any file'

for file_name, interval in average_intervals:
    print(f"{file_name}: {interval} seconds")

print(f"\nOverall average sampling interval across all files: {overall_average_interval} seconds")
# Out:
# Hu_Samsung_S22_csv-1706551395849.csv: 1.2313019390581716 seconds
# Hu_Samsung_S22_csv-1706554333642.csv: 1.8215527230590962 seconds
# Hu_Samsung_S22_csv-1706556488903.csv: 2.0304373522458627 seconds
# Hu_Samsung_S22_csv-1706629866070.csv: 14.495664739884393 seconds
# Hu_Samsung_S22_csv-1706645959366.csv: 15.088645262333594 seconds
# Hu_Samsung_S22_csv-1706648412755.csv: 13.77317719224871 seconds
# Hu_Samsung_S22_csv-1706719083524.csv: 19.207185764479203 seconds
# Hu_Samsung_S22_csv-1707167485257.csv: 0.7369337979094077 seconds
# Hu_Samsung_S22_csv-1707168946553.csv: 1.4846335697399526 seconds
# Hu_Samsung_S22_csv-1707169047177.csv: 1.3952180028129395 seconds
# Hu_Samsung_S22_csv-1707169378518.csv: 4.142857142857143 seconds
csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666143905551.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666143925579.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666143930889.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666144178897.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666283977858.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666284481675.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666385250356.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666717979729.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666718201515.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666844900709.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666845069838.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666902743826.csv: 0.0 seconds
# Li_Pixel_6_csv-1666903066604.csv: 0.0 seconds
# Li_Pixel_6_csv-1666910588148.csv: 0.0 seconds
# Li_Pixel_6_csv-1666911178839.csv: Insufficient data for interval calculation seconds
# Li_Pixel_6_csv-1666911326377.csv: 0.0 seconds
# Li_Pixel_6_csv-1666911552038.csv: 0.0 seconds
# Li_Pixel_6_csv-1666912251226.csv: 0.0 seconds
# Li_Pixel_6_csv-1666913635272.csv: 5.0 seconds
# Li_Pixel_6_csv-1668101143832.csv: 3.663157894736842 seconds
# Li_Samsung_S10_csv-1672872507940.csv: 2.7058823529411766 seconds
# Li_Samsung_S10_csv-1673044775501.csv: 2.6666666666666665 seconds
# Li_Samsung_S10_csv-1673044903212.csv: 2.1666666666666665 seconds
# Li_Samsung_S10_csv-1674091794910.csv: 4.199460916442049 seconds
# Li_Samsung_S10_csv-1674093009300.csv: 3.7282051282051283 seconds
# Li_Samsung_S10_csv-1674507931440.csv: 4.261875761266748 seconds
# Li_Samsung_S10_csv-1674586132384.csv: 2.640378548895899 seconds
# Li_Samsung_S10_csv-1674593675251.csv: 3.339171974522293 seconds
# Li_Samsung_S10_csv-1674595237096.csv: 2.914230019493177 seconds
# Li_Samsung_S21_csv-1669614843214.csv: 6.55 seconds
# Li_Samsung_S21_csv-1669675106111_flight.csv: 5.786407766990291 seconds
# Li_Samsung_S21_csv-1669676627475_flight.csv: 5.96 seconds
# Li_Samsung_S21_csv-1671507198416.csv: 3.727272727272727 seconds
# Li_Samsung_S21_csv-1671515190653.csv: 4.80897583429229 seconds
# Li_Samsung_S21_csv-1672726168810_flight.csv: 584.3825503355705 seconds
# Li_Samsung_S21_csv-1672736082052_flight.csv: 65.57142857142857 seconds
# Li_Samsung_S21_csv-1672739687207_flight.csv: 6.859259259259259 seconds
# Li_Samsung_S21_csv-1673744211840.csv: 4.384937238493724 seconds
# Li_Samsung_S21_csv-1673785930210_flight.csv: 13.296296296296296 seconds
# Li_Samsung_S21_csv-1673792926809_flight.csv: Insufficient data for interval calculation seconds
# Li_Samsung_S21_csv-1673820090376_flight.csv: Insufficient data for interval calculation seconds
# Li_Samsung_S21_csv-1673887278434.csv: 77.83234042553191 seconds
# Li_Samsung_S21_csv-1674120305812.csv: 6.367306155075939 seconds
# Li_Samsung_S21_csv-1674156084407_flight.csv: 185.19444444444446 seconds
# Li_Samsung_S21_csv-1674201551799.csv: 48.623313545601725 seconds
#
# Overall average sampling interval across all files: 14.683829566673568 seconds

# %%
import os
import pandas as pd
import numpy as np

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees).
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

def calculate_distance_for_file(csv_file):
    # Load the CSV file
    df = pd.read_csv(csv_file)
    
    # Calculate the distances
    distances = [
        haversine(lon1, lat1, lon2, lat2) 
        for lat1, lon1, lat2, lon2 in zip(df['latitude'][:-1], df['longitude'][:-1], df['latitude'][1:], df['longitude'][1:])
    ]
    
    # Sum the distances
    return sum(distances), len(df)

def calculate_cumulative_distance_and_row_count(directory):
    
    total_distance = 0
    total_row_count = 0
    
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            distance, row_count = calculate_distance_for_file(file_path)
            total_distance += distance
            total_row_count += row_count

    average_distance =  (total_distance/ total_row_count)*1000
    return total_distance, average_distance

# Example usage
directory = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed_remove_duplicate_rows'  # Replace this with the path to your directory
cumulative_distance, average_distance = calculate_cumulative_distance_and_row_count(directory)
print(f"Cumulative Distance Traversed: {cumulative_distance} km")
print(f"Average Distance: {average_distance} m")
# Out:
# Cumulative Distance Traversed: 8473.671461837745 km
# Average Distance: 66.48728471092323 m

# %%
import os
import pandas as pd
import numpy as np

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees).
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

def calculate_distance_for_file(csv_file):
    # Load the CSV file
    df = pd.read_csv(csv_file)
    
    # Calculate the distances
    distances = [
        haversine(lon1, lat1, lon2, lat2) 
        for lat1, lon1, lat2, lon2 in zip(df['latitude'][:-1], df['longitude'][:-1], df['latitude'][1:], df['longitude'][1:])
    ]
    
    # Sum the distances
    return sum(distances)

def calculate_cumulative_distance(directory):
    total_distance = 0
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            total_distance += calculate_distance_for_file(file_path)
    return total_distance

# Example usage
directory = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed_remove_duplicate_rows'  # Replace this with the path to your directory
cumulative_distance = calculate_cumulative_distance(directory)
print(f"Cumulative Distance Traversed: {cumulative_distance} km")

# %%
import os
import pandas as pd

# Specify the directory containing the CSV files
directory = 'C:\\Users\\ss6365\\Desktop\\Datasets\\Collected\\dataset_preprocessed'

# List all CSV files in the directory
csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]

# Initialize an identifier starting from 1
identifier = 1

# Iterate over each CSV file
for file_name in csv_files:
    # Construct the full file path
    file_path = os.path.join(directory, file_name)
    
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)
    
    # Add a new column 'identifier' with all rows having the same identifier
    df['identifier'] = identifier
    
    # Save the modified DataFrame back to the same CSV file
    df.to_csv(file_path, index=False)
    
    # Increment the identifier for the next file
    identifier += 1

print('All files have been processed and updated with an identifier.')

# %%
################# Data Security ####################

# %%
import os
import pandas as pd


# Input directory containing CSV files
input_directory = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\collected\\data\\utility'

# Output directory where the merged CSV file will be saved
output_directory = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\collected\\data'



# # List of important columns to keep
important_columns = ['identifier', 'longitude', 'latitude']  # Replace with your column names

# # Create a list to store dataframes from individual CSV files
dataframes = []

# # Iterate through CSV files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_directory, filename)
        df = pd.read_csv(file_path, usecols=important_columns)
        dataframes.append(df)

# # Concatenate dataframes vertically (along rows)
merged_df = pd.concat(dataframes, ignore_index=True)

# # Output file path for the merged CSV file
output_file_path = os.path.join(output_directory, 'merged_all_utility_subset.csv')

# # Save the merged dataframe to a CSV file
merged_df.to_csv(output_file_path, index=False)

print(f"Merged CSV file saved to {output_file_path}")
# Out:
# Merged CSV file saved to C:\Users\ss6365\Desktop\location_privacy_final\collected\data\merged_all_utility_subset.csv

# %%
import numpy as np


df = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\data\merged_all_utility_subset.csv')

def haversine(lat1, lon1, lat2, lon2):
    # Radius of the Earth in km
    R = 6371.0
    # Convert coordinates from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c
    return distance

def find_square_boundaries(lat, lon, distance_km):
    # Approximate conversions
    delta_lat = distance_km / 111  # 111 km per degree of latitude
    delta_lon = distance_km / (111 * np.cos(np.radians(lat)))  # Adjust for longitude
    return lat - delta_lat, lat + delta_lat, lon - delta_lon, lon + delta_lon


# Calculate the median (or mean) latitude and longitude
central_lat = df['latitude'].median()
central_lon = df['longitude'].median()


# Define the square region boundaries
lat_min, lat_max, lon_min, lon_max = find_square_boundaries(central_lat, central_lon, 2)

# Filter the DataFrame for points within the 1 km square
df_limit = df[(df['latitude'] >= lat_min) & (df['latitude'] <= lat_max) &
               (df['longitude'] >= lon_min) & (df['longitude'] <= lon_max)]

df_limit
# Out:
#        longitude   latitude  identifier
# 0     -77.680333  43.083838           1
# 1     -77.680991  43.083803           1
# 2     -77.681017  43.083802           1
# 3     -77.681042  43.083802           1
# 4     -77.681090  43.083802           1
# ...          ...        ...         ...
# 99218 -77.680445  43.083879          46
# 99219 -77.680442  43.083868          46
# 99220 -77.680441  43.083863          46
# 99221 -77.680442  43.083860          46
# 99222 -77.680442  43.083850          46
#
# [55425 rows x 3 columns]

# %%
import glob
import os
import pandas as pd

# Input and output directories
input_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected\data\utility'
output_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected\data\security'


# Calculate the boundaries based on the current file
lat_min = df_limit['latitude'].min()
lat_max = df_limit['latitude'].max()
lon_min = df_limit['longitude'].min()
lon_max = df_limit['longitude'].max()


# Iterate through CSV files in the input directory
for csv_file in glob.glob(os.path.join(input_directory, '*.csv')):
    # Load the CSV file
    df = pd.read_csv(csv_file)



    # Distance parameter (can be adjusted as needed)
    distance_km = 3

    # Define the square region boundaries and filter the DataFrame
    df_square = df[(df['latitude'] >= lat_min) & (df['latitude'] <= lat_max) &
                   (df['longitude'] >= lon_min) & (df['longitude'] <= lon_max)]

    # Check if the filtered DataFrame is empty (no data within boundaries)
    if df_square.empty:
        continue  # Skip saving if no data matches the criteria

    # Extract the base filename without extension
    base_filename = os.path.splitext(os.path.basename(csv_file))[0]
    
    # Create the new filename with distance_km
    new_filename = f"{base_filename}_{distance_km}km.csv"
    
    # Save the filtered DataFrame to the output directory with the new filename
    output_path = os.path.join(output_directory, new_filename)
    df_square.to_csv(output_path, index=False)

print("Processing complete.")
# Out:
# Processing complete.

# %%
# Input directory containing CSV files
input_directory = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\collected\\data\\security'

# Output directory where the merged CSV file will be saved
output_directory = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\collected\\data'



# # List of important columns to keep
important_columns = ['identifier', 'longitude', 'latitude']  # Replace with your column names

# # Create a list to store dataframes from individual CSV files
dataframes = []

# # Iterate through CSV files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_directory, filename)
        df = pd.read_csv(file_path, usecols=important_columns)
        dataframes.append(df)

# # Concatenate dataframes vertically (along rows)
merged_df = pd.concat(dataframes, ignore_index=True)

# # Output file path for the merged CSV file
output_file_path = os.path.join(output_directory, 'merged_all_security_subset_3km.csv')

# # Save the merged dataframe to a CSV file
merged_df.to_csv(output_file_path, index=False)

print(f"Merged CSV file saved to {output_file_path}")
# Out:
# Merged CSV file saved to C:\Users\ss6365\Desktop\location_privacy_final\collected\data\merged_all_security_subset_3km.csv

# %%
import pandas as pd
import os

def split_csv(input_file_path, output_directory, row_ranges):
    # Make sure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    # Read the input CSV file
    df = pd.read_csv(input_file_path)
    
    # Split the file based on the provided row ranges and save the splits
    for start, end in row_ranges:
        # Adjusting the end for Python's zero-based index and ensuring it doesn't exceed the DataFrame's length
        end = min(end, len(df))
        split_df = df.iloc[start:end]
        output_file_path = os.path.join(output_directory, f'rows_{start+1}_to_{end}.csv')
        split_df.to_csv(output_file_path, index=False)
        print(f'Saved: {output_file_path}')

# Example usage
input_file_path = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_Test\Hu_Samsung_S22_csv-1706551395849_3km.csv'  # Update this path
output_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary'  # Update this path

# Define your row ranges here, note that Python uses zero-based indexing
row_ranges = [
    (0, 20), (20, 40), (40, 60), (60, 80), # for 1 to 80
    (0, 50), (50, 100), (100, 150), (150, 200), # for 1 to 200 in steps of 50
    (0, 100), (100, 200) # for 1 to 200 in steps of 100
]

split_csv(input_file_path, output_directory, row_ranges)
# Out:
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_20.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_21_to_40.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_41_to_60.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_61_to_80.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_50.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_51_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_101_to_150.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_151_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_101_to_200.csv

# %%
import pandas as pd
import os

def calculate_row_ranges(total_rows, multiples):
    row_ranges = []
    for multiple in multiples:
        for start in range(0, total_rows, multiple):
            end = start + multiple
            # Only add the range if it doesn't exceed the total rows
            if end <= total_rows:
                row_ranges.append((start, end))
    return row_ranges

def split_csv(input_file_path, output_directory, multiples):
    # Ensure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    # Load the CSV
    df = pd.read_csv(input_file_path)
    total_rows = len(df)
    
    # Calculate row ranges based on multiples and total rows
    row_ranges = calculate_row_ranges(total_rows, multiples)
    
    # Split and save CSVs
    for start, end in row_ranges:
        split_df = df.iloc[start:end]
        output_file_path = os.path.join(output_directory, f'rows_{start+1}_to_{end}.csv')
        split_df.to_csv(output_file_path, index=False)
        print(f'Saved: {output_file_path}')

# Input file and output directory
input_file_path =  r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_Test\Hu_Samsung_S22_csv-1706556488903_3km.csv'  # Update this path
output_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary'  # Update this path

# Define your multiples here
multiples = [20, 50, 100, 200]

split_csv(input_file_path, output_directory, multiples)
# Out:
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_20.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_21_to_40.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_41_to_60.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_61_to_80.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_81_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_101_to_120.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_121_to_140.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_141_to_160.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_161_to_180.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_181_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_201_to_220.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_221_to_240.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_241_to_260.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_261_to_280.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_281_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_301_to_320.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_321_to_340.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_341_to_360.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_361_to_380.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_381_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_401_to_420.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_421_to_440.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_441_to_460.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_461_to_480.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_481_to_500.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_501_to_520.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_50.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_51_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_101_to_150.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_151_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_201_to_250.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_251_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_301_to_350.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_351_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_401_to_450.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_451_to_500.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_101_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_201_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_301_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_401_to_500.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_1_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\rows_201_to_400.csv

# %%
import pandas as pd
import os

def calculate_row_ranges(total_rows, multiples):
    row_ranges = []
    for multiple in multiples:
        for start in range(0, total_rows, multiple):
            end = start + multiple
            if end <= total_rows:
                row_ranges.append((start, end))
    return row_ranges

def split_csv(input_file_path, output_directory, multiples):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    df = pd.read_csv(input_file_path)
    total_rows = len(df)
    
    row_ranges = calculate_row_ranges(total_rows, multiples)
    
    for start, end in row_ranges:
        split_df = df.iloc[start:end]
        output_file_path = os.path.join(output_directory, os.path.basename(input_file_path).replace('.csv', f'_rows_{start+1}_to_{end}.csv'))
        split_df.to_csv(output_file_path, index=False)
        print(f'Saved: {output_file_path}')

def process_all_csv(input_directory, output_directory, multiples):
    # Iterate over all files in the input directory
    for filename in os.listdir(input_directory):
        if filename.endswith('.csv'):
            file_path = os.path.join(input_directory, filename)
            print(f'Processing: {file_path}')
            split_csv(file_path, output_directory, multiples)

# Directory containing the CSV files
input_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security'  # Update this path

# Output directory for the split files
output_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary'  # Update this path

# Define your multiples here
multiples = [20, 50, 100, 200]

# Process all CSV files in the directory
process_all_csv(input_directory, output_directory, multiples)
# Out:
# Processing: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security\Hu_Samsung_S22_csv-1706551395849_3km.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_20.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_21_to_40.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_41_to_60.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_61_to_80.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_81_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_101_to_120.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_121_to_140.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_141_to_160.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_161_to_180.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_181_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_201_to_220.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_221_to_240.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_241_to_260.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_50.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_51_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_101_to_150.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_151_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_201_to_250.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_101_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_200.csv
# Processing: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security\Hu_Samsung_S22_csv-1706554333642_3km.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_20.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_21_to_40.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_41_to_60.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_61_to_80.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_81_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_101_to_120.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_121_to_140.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_141_to_160.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_161_to_180.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_181_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_201_to_220.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_221_to_240.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_241_to_260.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_50.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_51_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_101_to_150.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_151_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_201_to_250.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_101_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_200.csv
# Processing: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security\Hu_Samsung_S22_csv-1706556488903_3km.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_20.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_21_to_40.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_41_to_60.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_61_to_80.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_81_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_101_to_120.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_121_to_140.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_141_to_160.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_161_to_180.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_181_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_220.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_221_to_240.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_241_to_260.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_261_to_280.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_281_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_301_to_320.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_321_to_340.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_341_to_360.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_361_to_380.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_381_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_401_to_420.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_421_to_440.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_441_to_460.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_461_to_480.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_481_to_500.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_501_to_520.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_50.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_51_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_101_to_150.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_151_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_250.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_251_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_301_to_350.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_351_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_401_to_450.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_451_to_500.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_101_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_301_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_401_to_500.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_400.csv
# Processing: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security\Hu_Samsung_S22_csv-1706629866070_3km.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_1_to_20.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_21_to_40.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_41_to_60.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_61_to_80.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_81_to_100.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_101_to_120.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_121_to_140.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_141_to_160.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_161_to_180.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_181_to_200.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_201_to_220.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_221_to_240.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_241_to_260.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_261_to_280.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_281_to_300.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_301_to_320.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_321_to_340.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_341_to_360.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_361_to_380.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_381_to_400.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_401_to_420.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_421_to_440.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows_441_to_460.csv
# Saved: C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary\Hu_Samsung_S22_csv-1706629866070_3km_rows
# %%
len(df)
# Out:
# 537

# %%
import pandas as pd
import os
import shutil

def move_files_based_on_row_count(source_directory, target_directories, row_counts):
    # Iterate over all files in the source directory
    for filename in os.listdir(source_directory):
        if filename.endswith('.csv'):
            file_path = os.path.join(source_directory, filename)
            # Read the CSV file to determine its row count
            try:
                df = pd.read_csv(file_path)
                row_count = len(df)  # Adding 1 for the header
            except Exception as e:
                print(f"Error reading {filename}: {e}")
                continue
            
            # Check if this row count is one of the specified counts to move
            if row_count in row_counts:
                # Determine the target directory for this row count
                target_directory = target_directories.get(row_count)
                if target_directory:
                    # Ensure the target directory exists
                    if not os.path.exists(target_directory):
                        os.makedirs(target_directory)
                    
                    # Move the
                    # Move the file
                    shutil.move(file_path, os.path.join(target_directory, filename))
                    print(f'Moved: {filename} to {target_directory}')
                else:
                    print(f"No target directory specified for files of length {row_count}.")
            else:
                print(f'File {filename} is not in the specified size range to move.')

# Example usage
source_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary'
target_directories = {
    20: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20',
    50: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50',
    100: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100',
    200: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200',
}
sizes_kb = [20, 50, 100, 200]

move_files_based_on_row_count(source_directory, target_directories, sizes_kb)
# Out:
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_101_to_120.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_101_to_150.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_101_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_121_to_140.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_141_to_160.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_151_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_161_to_180.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_181_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_20.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_1_to_50.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_201_to_220.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_201_to_250.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_21_to_40.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_221_to_240.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_241_to_260.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_41_to_60.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_51_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_61_to_80.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706551395849_3km_rows_81_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_101_to_120.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_101_to_150.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_101_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_121_to_140.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_141_to_160.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_151_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_161_to_180.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_181_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_20.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_1_to_50.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_201_to_220.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_201_to_250.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_21_to_40.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_221_to_240.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_241_to_260.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_41_to_60.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_51_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_61_to_80.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706554333642_3km_rows_81_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_101_to_120.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_101_to_150.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_101_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_121_to_140.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_141_to_160.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_151_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_161_to_180.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_181_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_20.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_1_to_50.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_220.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_250.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_201_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_21_to_40.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_221_to_240.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_241_to_260.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_251_to_300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_261_to_280.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_281_to_300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_301_to_320.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_301_to_350.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_301_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_321_to_340.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_341_to_360.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_351_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_361_to_380.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_381_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_401_to_420.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_401_to_450.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_401_to_500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_41_to_60.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_421_to_440.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_441_to_460.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_451_to_500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_461_to_480.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_481_to_500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_501_to_520.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_51_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_61_to_80.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706556488903_3km_rows_81_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1001_to_1020.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1001_to_1050.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1001_to_1100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1001_to_1200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_101_to_120.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_101_to_150.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_101_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1021_to_1040.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1041_to_1060.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1051_to_1100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1061_to_1080.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1081_to_1100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1101_to_1120.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1101_to_1150.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1101_to_1200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1121_to_1140.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1141_to_1160.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1151_to_1200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1161_to_1180.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1181_to_1200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1201_to_1220.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1201_to_1250.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1201_to_1300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1201_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_121_to_140.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1221_to_1240.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1241_to_1260.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1251_to_1300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1261_to_1280.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1281_to_1300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1301_to_1320.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1301_to_1350.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1301_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1321_to_1340.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1341_to_1360.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1351_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1361_to_1380.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1381_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1401_to_1420.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1401_to_1450.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1401_to_1500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_141_to_160.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1421_to_1440.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1441_to_1460.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_1451_to_1500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1706629866070_3km_rows_
csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1281_to_1300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1301_to_1320.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1301_to_1350.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1301_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1321_to_1340.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1341_to_1360.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1351_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1361_to_1380.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1381_to_1400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1401_to_1420.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1401_to_1450.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1401_to_1500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_141_to_160.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1421_to_1440.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1441_to_1460.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1451_to_1500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1461_to_1480.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1481_to_1500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1501_to_1520.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1501_to_1550.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_151_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1521_to_1540.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1541_to_1560.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_161_to_180.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_181_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1_to_20.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1_to_200.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_1_to_50.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_201_to_220.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_201_to_250.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_201_to_300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_201_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_21_to_40.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_221_to_240.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_241_to_260.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_251_to_300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_261_to_280.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_281_to_300.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_301_to_320.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_301_to_350.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_301_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_321_to_340.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_341_to_360.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_351_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_361_to_380.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_381_to_400.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_401_to_420.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_401_to_450.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_401_to_500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_401_to_600.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_41_to_60.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_421_to_440.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_441_to_460.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_451_to_500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_461_to_480.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_481_to_500.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_501_to_520.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_501_to_550.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_501_to_600.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_51_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_521_to_540.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_541_to_560.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_551_to_600.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_561_to_580.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_581_to_600.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_601_to_620.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_601_to_650.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_601_to_700.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_601_to_800.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_61_to_80.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_621_to_640.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_641_to_660.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_651_to_700.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_661_to_680.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_681_to_700.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_701_to_720.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_701_to_750.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_701_to_800.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_721_to_740.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_741_to_760.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_751_to_800.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_761_to_780.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_781_to_800.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_801_to_1000.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_801_to_820.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_801_to_850.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_801_to_900.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_81_to_100.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_821_to_840.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_841_to_860.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_851_to_900.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_861_to_880.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_881_to_900.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_901_to_1000.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_901_to_920.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_901_to_950.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_921_to_940.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_941_to_960.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_951_to_1000.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_961_to_980.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20
# Moved: Hu_Samsung_S22_csv-1711635308022_3km_rows_981_to_1000.csv to C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20

# %%
import pandas as pd
import os
import shutil

def move_files_based_on_row_count(source_directory, target_directories, row_counts):
    # Iterate over all files in the source directory
    for filename in os.listdir(source_directory):
        if filename.endswith('.csv'):
            file_path = os.path.join(source_directory, filename)
            # Read the CSV file to determine its row count
            try:
                df = pd.read_csv(file_path)
                row_count = len(df)  # Adding 1 for the header
            except Exception as e:
                print(f"Error reading {filename}: {e}")
                continue
            
            # Check if this row count is one of the specified counts to move
            if row_count in row_counts:
                # Determine the target directory for this row count
                target_directory = target_directories.get(row_count)
                if target_directory:
                    # Ensure the target directory exists
                    if not os.path.exists(target_directory):
                        os.makedirs(target_directory)
                    
                    # Move the
                    # Move the file
                    shutil.move(file_path, os.path.join(target_directory, filename))
                    print(f'Moved: {filename} to {target_directory}')
                else:
                    print(f"No target directory specified for files of length {row_count}.")
            else:
                print(f'File {filename} is not in the specified size range to move.')

# Example usage
source_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\temporary'
target_directories = {
    20: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20',
    50: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50',
    100: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100',
    200: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200',
}
sizes_kb = [20, 50, 100, 200]

move_files_based_on_size(source_directory, target_directories, sizes_kb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 46
#      38 target_directories = {
#      39     20: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_20',
#      40     50: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_50',
#      41     100: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_100',
#      42     200: r'C:\Users\ss6365\Desktop\location_privacy_final\collected_trace\data\security_200',
#      43 }
#      44 sizes_kb = [20, 50, 100, 200]
# ---> 46 move_files_based_on_size(source_directory, target_directories, sizes_kb)
#
# NameError: name 'move_files_based_on_size' is not defined
