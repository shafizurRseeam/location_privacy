# %%
import numpy as np
import pandas as pd
import os

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

def plot_l2_distance_effect_radius(base_directory, dataset_name):
    # Base directory for the perturbed data
    base_directory_input = os.path.join(base_directory, dataset_name, 'perturbed')
    
    # Epsilon values and Delta configurations
    epsilon_values = [0.1, 1, 5]
    radius = [20, 50, 200]
    l2_distances = []

    for radi in radius:
        x_values = []
        for epsilon in epsilon_values:
            file_name = f'merged_our_bl_{radi}_delta_5_{epsilon}.csv'
            file_path = os.path.join(base_directory_input, f'our_bl_{radi}_delta_5', file_name)
            df = pd.read_csv(file_path)
            mean_value = df['l2_distance'].mean()
            x_values.append(mean_value)
        l2_distances.append(x_values)

    # Plot setup
    fig, ax = plt.subplots(figsize=(10, 6))
    colors = ['#1F77B4', '#FF7F0E', '#2CA02C']
    width = 0.2
    delta_gap = 0.1
    group_width = len(epsilon_values) * width + delta_gap
    x = np.arange(len(radius)) * group_width

    # Plotting bars
    for radi_index, radi in enumerate(radius):
        for bar_index, epsilon in enumerate(epsilon_values):
            bar_position = x[radi_index] + bar_index * width
            bar_height = l2_distances[radi_index][bar_index]
            ax.bar(bar_position, bar_height, width, color=colors[radi_index], edgecolor='black')

            # Text above bars
            text_y_position = bar_height 
            ax.text(bar_position-width/2, text_y_position, f'$\epsilon$ = {epsilon}',
                    ha='left', va='bottom', fontsize=20, rotation=45)

    # Customization
    ax.set_xlabel('$r_b$', fontsize=28)
    ax.set_ylabel('Average $L_2$ Distance', fontsize=28)
    ax.set_xticks(x + width * (len(epsilon_values) - 1) / 2)
    ax.set_xticklabels(radius)
    plt.tick_params(axis='both', which='major', labelsize=28)
    plt.ylim(0, max(l2_distances[2]) * 1.3)

    # # Save and display
    # save_dir_png = os.path.join(base_directory, dataset_name, 'figure', 'png')
    # save_dir_svg = os.path.join(base_directory, dataset_name, 'figure', 'svg')
    # os.makedirs(save_dir_png, exist_ok=True)
    # os.makedirs(save_dir_svg, exist_ok=True)
    # pathpng = os.path.join(save_dir_png, f'{dataset_name}_l2_delta_effect.png')
    # pathsvg = os.path.join(save_dir_svg, f'{dataset_name}_l2_delta_effect.svg')
    # plt.savefig(pathpng, dpi=300, bbox_inches='tight')
    # plt.savefig(pathsvg, format='svg', bbox_inches='tight')
    plt.show()

# Example usage:
base_directory = "C:\\Users\\ss6365\\Desktop\\location_privacy_final"
dataset_name = 'uci'  # Change 'uci' to any other directory name as needed
plot_l2_distance_effect_radius(base_directory, dataset_name)

# %%
base_directory_input_O_b50_d5 = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_50_delta_5'


file_name_1_O_b50_d5 = 'merged_our_bl_50_delta_5_0.1.csv'
file_name_2_O_b50_d5 = 'merged_our_bl_50_delta_5_0.2.csv'
file_name_3_O_b50_d5 = 'merged_our_bl_50_delta_5_0.5.csv'
#file_name_4_O_b50_d5 = 'merged_our_0.7.csv'
file_name_5_O_b50_d5 = 'merged_our_bl_50_delta_5_1.csv'
file_name_6_O_b50_d5 = 'merged_our_bl_50_delta_5_2.csv'
file_name_7_O_b50_d5 = 'merged_our_bl_50_delta_5_3.csv'
file_name_8_O_b50_d5 = 'merged_our_bl_50_delta_5_4.csv'
file_name_9_O_b50_d5 = 'merged_our_bl_50_delta_5_5.csv'



file_path1_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_1_O_b50_d5)
file_path2_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_2_O_b50_d5)
file_path3_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_3_O_b50_d5)
#file_path4_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_4_O_b50_d5)
file_path5_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_5_O_b50_d5)
file_path6_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_6_O_b50_d5)
file_path7_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_7_O_b50_d5)
file_path8_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_8_O_b50_d5)
file_path9_O_b50_d5 = os.path.join(base_directory_input_O_b50_d5, file_name_9_O_b50_d5)






df1_O_b50_d5 = pd.read_csv(file_path1_O_b50_d5)
df2_O_b50_d5 = pd.read_csv(file_path2_O_b50_d5)
df3_O_b50_d5 = pd.read_csv(file_path3_O_b50_d5)
#df4_O_b50_d5 = pd.read_csv(file_path4_O_b50_d5)
df5_O_b50_d5 = pd.read_csv(file_path5_O_b50_d5)
df6_O_b50_d5 = pd.read_csv(file_path6_O_b50_d5)
df7_O_b50_d5 = pd.read_csv(file_path7_O_b50_d5)
df8_O_b50_d5 = pd.read_csv(file_path8_O_b50_d5)
df9_O_b50_d5 = pd.read_csv(file_path9_O_b50_d5)

# %%
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]
dataframes_O_b50_d5 = [df1_O_b50_d5, df2_O_b50_d5, df3_O_b50_d5, df5_O_b50_d5, df6_O_b50_d5, df7_O_b50_d5, df8_O_b50_d5, df9_O_b50_d5]
x_values_O_b50_d5 = []

for df in dataframes_O_b50_d5:
    # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
    mean_value = df['l2_distance'].mean()  # This calculates the mean across all columns and then the mean of those means
    x_values_O_b50_d5.append(mean_value)

# x_values_O_t_b50_d5 = []

# for df in dataframes_O_b50_d5:
#     # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
#     mean_value = (df['distance_x_z'].sum())/file_count  # This calculates the mean across all columns and then the mean of those means
#     x_values_O_t_b50_d5.append(mean_value)

# %%
base_directory_input_O_b500_d5 = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_500_delta_5'

file_name_1_O_b500_d5 = 'merged_our_bl_500_delta_5_0.1.csv'
file_name_2_O_b500_d5=  'merged_our_bl_500_delta_5_0.2.csv'
file_name_3_O_b500_d5 = 'merged_our_bl_500_delta_5_0.5.csv'
#file_name_4_O_b50_d10 = 'merged_our_0.7.csv'
file_name_5_O_b500_d5 = 'merged_our_bl_500_delta_5_1.csv'
file_name_6_O_b500_d5 = 'merged_our_bl_500_delta_5_2.csv'
file_name_7_O_b500_d5 = 'merged_our_bl_500_delta_5_3.csv'
file_name_8_O_b500_d5 = 'merged_our_bl_500_delta_5_4.csv'
file_name_9_O_b500_d5 = 'merged_our_bl_500_delta_5_5.csv'



file_path1_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_1_O_b500_d5 )
file_path2_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_2_O_b500_d5 )
file_path3_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_3_O_b500_d5 )
#file_path4_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_4_O_b50_d10 )
file_path5_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_5_O_b500_d5 )
file_path6_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_6_O_b500_d5 )
file_path7_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_7_O_b500_d5 )
file_path8_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_8_O_b500_d5 )
file_path9_O_b500_d5 = os.path.join(base_directory_input_O_b500_d5, file_name_9_O_b500_d5 )






df1_O_b500_d5 = pd.read_csv(file_path1_O_b500_d5)
df2_O_b500_d5 = pd.read_csv(file_path2_O_b500_d5)
df3_O_b500_d5 = pd.read_csv(file_path3_O_b500_d5)
#df4_O_b50_d10 = pd.read_csv(file_path4_O_b50_d10)
df5_O_b500_d5 = pd.read_csv(file_path5_O_b500_d5)
df6_O_b500_d5 = pd.read_csv(file_path6_O_b500_d5)
df7_O_b500_d5 = pd.read_csv(file_path7_O_b500_d5)
df8_O_b500_d5 = pd.read_csv(file_path8_O_b500_d5)
df9_O_b500_d5 = pd.read_csv(file_path9_O_b500_d5)

# %%
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]
dataframes_O_b500_d5 = [df1_O_b500_d5, df2_O_b500_d5, df3_O_b500_d5, df5_O_b500_d5, df6_O_b500_d5, df7_O_b500_d5, df8_O_b500_d5, df9_O_b500_d5]
x_values_O_b500_d5= []

for df in dataframes_O_b500_d5:
    # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
    mean_value = df['l2_distance'].mean()  # This calculates the mean across all columns and then the mean of those means
    x_values_O_b500_d5.append(mean_value)

# x_values_O_t_b50_d10 = []

# for df in dataframes_O_b50_d10:
#     # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
#     mean_value = (df['distance_x_z'].sum())/file_count  # This calculates the mean across all columns and then the mean of those means
#     x_values_O_t_b50_d10.append(mean_value)

# %%
base_directory_input_O_b1000_d5 = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_1000_delta_5'

file_name_1_O_b1000_d5 = 'merged_our_bl_1000_delta_5_0.1.csv'
file_name_2_O_b1000_d5=  'merged_our_bl_1000_delta_5_0.2.csv'
file_name_3_O_b1000_d5 = 'merged_our_bl_1000_delta_5_0.5.csv'
#file_name_4_O_b50_d10 = 'merged_our_0.7.csv'
file_name_5_O_b1000_d5 = 'merged_our_bl_1000_delta_5_1.csv'
file_name_6_O_b1000_d5 = 'merged_our_bl_1000_delta_5_2.csv'
file_name_7_O_b1000_d5 = 'merged_our_bl_1000_delta_5_3.csv'
file_name_8_O_b1000_d5 = 'merged_our_bl_1000_delta_5_4.csv'
file_name_9_O_b1000_d5 = 'merged_our_bl_1000_delta_5_5.csv'



file_path1_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_1_O_b1000_d5 )
file_path2_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_2_O_b1000_d5 )
file_path3_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_3_O_b1000_d5 )
#file_path4_O_b50_d10 = os.path.join(base_directory_input_O_b50_d10, file_name_4_O_b50_d10 )
file_path5_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_5_O_b1000_d5 )
file_path6_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_6_O_b1000_d5 )
file_path7_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_7_O_b1000_d5 )
file_path8_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_8_O_b1000_d5 )
file_path9_O_b1000_d5 = os.path.join(base_directory_input_O_b1000_d5, file_name_9_O_b1000_d5 )






df1_O_b1000_d5 = pd.read_csv(file_path1_O_b1000_d5)
df2_O_b1000_d5 = pd.read_csv(file_path2_O_b1000_d5)
df3_O_b1000_d5 = pd.read_csv(file_path3_O_b1000_d5)
#df4_O_b50_d10 = pd.read_csv(file_path4_O_b50_d10)
df5_O_b1000_d5 = pd.read_csv(file_path5_O_b1000_d5)
df6_O_b1000_d5 = pd.read_csv(file_path6_O_b1000_d5)
df7_O_b1000_d5 = pd.read_csv(file_path7_O_b1000_d5)
df8_O_b1000_d5 = pd.read_csv(file_path8_O_b1000_d5)
df9_O_b1000_d5 = pd.read_csv(file_path9_O_b1000_d5)

# %%
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]
dataframes_O_b1000_d5 = [df1_O_b1000_d5, df2_O_b1000_d5, df3_O_b1000_d5, df5_O_b1000_d5, df6_O_b1000_d5, df7_O_b1000_d5, df8_O_b1000_d5, df9_O_b1000_d5]
x_values_O_b1000_d5= []

for df in dataframes_O_b1000_d5:
    # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
    mean_value = df['l2_distance'].mean()  # This calculates the mean across all columns and then the mean of those means
    x_values_O_b1000_d5.append(mean_value)

# x_values_O_t_b50_d10 = []

# for df in dataframes_O_b50_d10:
#     # Calculate mean of all columns, you can also select specific columns using df[['col1', 'col2']].mean()
#     mean_value = (df['distance_x_z'].sum())/file_count  # This calculates the mean across all columns and then the mean of those means
#     x_values_O_t_b50_d10.append(mean_value)

# %%
x_values_O_b50_d5
# Out:
# [9.420370863504129,
#  4.878754916990195,
#  2.238791987397673,
#  1.379585750056117,
#  1.0593117669221954,
#  0.9039921625797009,
#  0.9039921625797009,
#  0.7522403041338126]

# %%
x_values_O_b500_d5
# Out:
# [9.420370863504129,
#  4.878754916990195,
#  2.238791987397673,
#  1.379585750056117,
#  1.0593117669221954,
#  0.9039921625797009,
#  0.9039921625797009,
#  0.7522403041338126]

# %%
x_values_O_b50_d5=[x_values_O_b50_d5[0], x_values_O_b50_d5[3], x_values_O_b50_d5[7]]
x_values_O_b100_d5=[x_values_O_b500_d5[0], x_values_O_b500_d5[3], x_values_O_b500_d5[7]]
x_values_O_b200_d5=[x_values_O_b1000_d5[0], x_values_O_b1000_d5[3], x_values_O_b1000_d5[7]]

# %%
x_values_O_b50_d5
# Out:
# [9.138594414548095, 1.320525418548137, 0.6766161917662301]

# %%
x_values_O_b100_d5
# Out:
# [9.138594414548095, 1.320525418548137, 0.6766161917662301]

# %%
x_values_O_b200_d5
# Out:
# [9.138594414548095, 1.320525418548137, 0.6766161917662301]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your data
epsilon_values = [0.1, 1,  5]

BL = [ 50, 100, 200]

l2_distances_b_50 = x_values_O_b50_d5
l2_distances_b_100 = x_values_O_b100_d5
l2_distances_b_200 = x_values_O_b200_d5
l2_distances = [x_values_O_b50_d5, x_values_O_b100_d5, x_values_O_b200_d5]
n_bars = len(l2_distances_b_50)



# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Light color theme
colors = ['lightblue', 'lightgreen', 'lightcoral']
patterns = ['/', '\\', '|']

# Bar setup
width = 0.2
n_bars = len(l2_distances_b_50)
delta_gap = 0.1
group_width = n_bars * width + delta_gap
x = np.arange(len(BL)) * group_width

# Plotting bars with light colors and hatch patterns
for bl_index, bl in enumerate(BL):
    for bar_index in range(n_bars):
        bar_position = x[bl_index] + bar_index * width
        bar_height = l2_distances[bl_index][bar_index]
        ax.bar(bar_position, bar_height, width,
               color=colors[bl_index], edgecolor='black',
               hatch=patterns[bar_index] * 3, alpha=0.7)
        ax.text(bar_position, bar_height, f'$\epsilon$ = {epsilon_values[bar_index]}', 
                ha='center', va='bottom', fontsize=16)

# Customization of the plot
ax.set_xlabel('$\delta$', fontsize=20)
ax.set_ylabel('Average $L_2$-Distance', fontsize=20)
ax.set_xticks(x + width * (n_bars - 1) / 2)
ax.set_xticklabels(BL)
plt.tick_params(axis='both', which='major', labelsize=20)

# Customizing the grid
ax.grid(True, linestyle='-', alpha=0.3)  # Major grid with solid lines
ax.minorticks_on()  # Enable minor ticks
ax.grid(which='minor', linestyle=':', alpha=0.2)  # Minor grid with dotted lines

plt.tight_layout()


# Saving the plot as a high-definition PNG
#pathpng = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\png\\Geolife_BoundingRadius'
#plt.savefig(pathpng, dpi=300, bbox_inches='tight')

# Saving the plot as an SVG
#pathsvg = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\svg\\Geolife_BoundingRadius'
#plt.savefig(pathsvg, format='svg', bbox_inches='tight')
# Display the plot
# Show the plot
plt.show()

# %%
df = pd.read_csv('C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_50_delta_5\\merged_our_bl_50_delta_5_0.1.csv')
df['l2_distance'].mean()
# Out:
# 9.420370863504129

# %%
df = pd.read_csv('C:\\Users\\ss6365\\Desktop\\location_privacy_final\\uci\\perturbed\\our_bl_500_delta_5\\merged_our_bl_500_delta_5_0.1.csv')
df['l2_distance'].mean()
# Out:
# 9.420370863504129
