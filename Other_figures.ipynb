# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.ticker as mticker
# Example data (replace with your actual data)
# Example data (replace with your actual data)

epsilon_values = [0.1,0.2,0.5,1,2,3,4,5]





BR_Laplace =  [ 0.3114789901284179,
0.2140298768236219,
0.1792172621647593,
0.17074342622521185,
0.16982615532453915,
0.16799161352319383,
0.1688652048571678,
0.1691709618240587]




BR_Staircase =[0.27264785533327507,
0.2034157421158382,
0.17467458722809467,
0.16978247575784047,
0.16947671879094958,
0.16960775749104567,
0.16842840919018082,
0.16838472962348214,]




BR_our_bl_50_delta_5 = [0.45330654319909147,
0.31899187560059405,
0.224294574997816,
0.1989604263125709,
0.1903555516729274,
0.18729798200401854,
0.187953175504499,
0.1873853411374159]

BR_Laplace_delta = [0.45330654319909147,
0.31899187560059405,
0.224294574997816,
0.1989604263125709,
0.1903555516729274,
0.18729798200401854,
0.187953175504499,
0.1873853411374159]

# %%
df = pd.read_csv('bsm_ln_200_Geolife.csv')
df
# Out:
#    Suffix   Laplace  Staircase  Our_bl_50_delta_5  LaplaceDelta5
# 0     0.1  0.424159   0.375772           0.526424            NaN
# 1     0.2  0.353123   0.332189           0.429307            NaN
# 2     0.5  0.304393   0.305079           0.326012            NaN
# 3     1.0  0.299245   0.300618           0.317433            NaN
# 4     2.0  0.300961   0.299931           0.304393            NaN
# 5     3.0  0.298216   0.299588           0.298559            NaN
# 6     4.0  0.300618   0.301647           0.303363            NaN
# 7     5.0  0.299588   0.301990           0.300961            NaN

# %%
BR_Laplace = df['Laplace']
BR_Staircase = df['Staircase']
BR_our_bl_50_delta_5 = df['Our_bl_50_delta_5']
BR_Laplace_delta = df['Our_bl_50_delta_5']

# %%
epsilon_values = [0.1,0.2,0.5,1,2,3,4,5]


# Define lines
line1 = {'x': epsilon_values, 'y': BR_Laplace, 'label': '$PLM$', 'color': '#1F77B4', 'marker': 'D', 'linestyle': 'solid', 'markersize': 12}
line2 = {'x': epsilon_values, 'y': BR_Staircase, 'label': '$PSM$', 'color': '#FF7F0E', 'marker': 'o', 'linestyle': 'solid', 'markersize': 12}
line3 = {'x': epsilon_values, 'y': BR_our_bl_50_delta_5, 'label': '$PSM_i (r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linestyle': 'solid', 'markersize': 12}
line4 = {'x': epsilon_values, 'y': BR_Laplace_delta, 'label': '$PLM(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linestyle': 'solid', 'markersize': 12}


# Increase the figure size for better readability
plt.figure(figsize=(10, 6))
# Improved line styles and markers
plt.plot(line1['x'], line1['y'], label=line1['label'], color=line1['color'], marker=line1['marker'], linestyle=line1['linestyle'], linewidth=2,markersize=line1['markersize'])
plt.plot(line2['x'], line2['y'], label=line2['label'], color=line2['color'], marker=line2['marker'], linestyle=line2['linestyle'], linewidth=2,markersize=line2['markersize'])
plt.plot(line3['x'], line3['y'], label=line3['label'], color=line3['color'], marker=line3['marker'], linestyle=line3['linestyle'], linewidth=2,markersize=line3['markersize'])
plt.plot(line4['x'], line4['y'], label=line4['label'], color=line4['color'], marker=line4['marker'], linestyle=line4['linestyle'], linewidth=2,markersize=line4['markersize'], alpha=0.6)


# Log scale for x-axis and setting specific ticks and labels
plt.xlabel('$\epsilon$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)
#plt.title('Geolife (Per Point)')
# Log scale for x-axis and setting specific ticks and labels
plt.xscale('log')
plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)
# Adding legend
legend = plt.legend( fontsize=28, frameon=True)
#plt.legend(loc = 'upper left', fontsize=26)
frame = legend.get_frame()
#frame.set_color('black')  # Set the frame color
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width
# Show grid
#plt.grid(True, which="both", ls="--", color='gray', alpha=0.4)
#plt.gca().yaxis.set_major_formatter(mticker.ScalarFormatter(useMathText=True))
#plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
#plt.gca().yaxis.get_offset_text().set_size(18)
plt.tight_layout()

# Saving the plot as a high-definition PNG
#pathpng = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\PNG\\Geolife_Bayes_Risk_log_200aa'
#plt.savefig(pathpng, dpi=300, bbox_inches='tight')

# Saving the plot as an SVG
#pathsvg = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\svg\\Geolife_L1Distance_delta_5'
#plt.savefig(pathsvg, format='svg', bbox_inches='tight')
# Display the plot
plt.show()

# %%
Laplace = [0.00012435, 0.00012184, 0.00012628, 0.00012752]
staircase = [0.00012224, 0.00012453,0.00012568, 0.00012527]
staircase_intermediate = [0.00046442,0.00036278, 0.00045037,  0.00043455]
laplace_delta = [0.00021473, 0.00019572, 0.00021386, 0.00020675]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
datasets = ['T-drive', 'Geolife', 'UCI', 'AR']
Laplace = np.array([0.00012435, 0.00012184, 0.00012628, 0.00012752]) * 1e3
staircase = np.array([0.00012224, 0.00012453,0.00012568, 0.00012527]) * 1e3
staircase_intermediate = np.array([0.00046442,0.00036278, 0.00045037,  0.00043455]) * 1e3
laplace_delta = np.array([0.00021473, 0.00019572, 0.00021386, 0.00020675]) * 1e3

# Colors and labels taken from the style of the line plot
colors = ['#1F77B4', '#FF7F0E', '#2CA02C', '#DC143C']
labels = ['$PLM$', '$PSM$', '$PSM_i(r_b = 50, δ = 5)$', '$PLM(δ=5)$']

# Set the positions and width for the bars
pos = np.arange(len(datasets))
bar_width = 0.20

# Plotting the bars with the new style
plt.figure(figsize=(10, 6))  # Match the figure size
for i, (data, color, label) in enumerate(zip([Laplace, staircase, staircase_intermediate, laplace_delta], colors, labels)):
    plt.bar(pos + i * bar_width, data, bar_width, label=label, color=color)

# Adding labels and title
#plt.xlabel('Datasets', fontsize=28)
plt.ylabel('Runtime (µs)', fontsize=28)
#plt.title('Runtime Comparison')

# Positioning the x-ticks
plt.xticks(pos + 1.5 * bar_width, datasets, fontsize=28)

# Adding the legend with the modified style
legend = plt.legend(fontsize=28, frameon=True)
frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width

# Setting the tick parameters
plt.tick_params(axis='both', which='major', labelsize=28)

plt.tight_layout()  # Adjust the layout
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
datasets = ['T-drive', 'Geolife', 'UCI', 'AR']
Laplace = np.array([0.00012435, 0.00012184, 0.00012628, 0.00012752]) * 1e3
staircase = np.array([0.00012224, 0.00012453,0.00012568, 0.00012527]) * 1e3
staircase_intermediate = np.array([0.00046442,0.00036278, 0.00045037,  0.00043455]) * 1e3
laplace_delta = np.array([0.00021473, 0.00019572, 0.00021386, 0.00020675]) * 1e3

# Colors and labels taken from the style of the line plot
colors = ['#1F77B4', '#FF7F0E', '#2CA02C', '#DC143C']
labels = ['$PLM$', '$PSM$', '$PSM_i(r_b = 50, δ = 5)$', '$PLM(δ=5)$']

# Set the positions and width for the bars
pos = np.arange(len(datasets))
bar_width = 0.20

# Plotting the bars with the new style
fig, ax = plt.subplots(figsize=(10, 8))  # Increase figure size to accommodate legend

for i, (data, color, label) in enumerate(zip([Laplace, staircase, staircase_intermediate, laplace_delta], colors, labels)):
    ax.bar(pos + i * bar_width, data, bar_width, label=label, color=color)

# Adding labels and title
#ax.set_xlabel('Datasets', fontsize=28)
ax.set_ylabel('Runtime (ms)', fontsize=28)
#ax.set_title('Runtime Comparison')

# Positioning the x-ticks
ax.set_xticks(pos + 1.5 * bar_width)
ax.set_xticklabels(datasets, fontsize=28)

# Adding the legend with the modified style
# Reduce the handle length to decrease the space between the legend symbol and text
legend = ax.legend(fontsize=28, loc='upper center', bbox_to_anchor=(0.5, 1.32), fancybox=True, shadow=True, ncol=2, handlelength=1.2)

frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width

# Setting the tick parameters
ax.tick_params(axis='both', which='major', labelsize=28)

# Adjust the layout to make room for the legend outside of the plot
plt.subplots_adjust(top=0.75)
pathpng = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\png\\Runtime_datasets'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Sample data
datasets = ['T-drive', 'Geolife', 'UCI', 'AR']
Laplace = np.array([0.00012435, 0.00012184, 0.00012628, 0.00012752]) * 1e3
staircase = np.array([0.00012224, 0.00012453,0.00012568, 0.00012527]) * 1e3
staircase_intermediate = np.array([0.00046442,0.00036278, 0.00045037,  0.00043455]) * 1e3
laplace_delta = np.array([0.00021473, 0.00019572, 0.00021386, 0.00020675]) * 1e3

# Sample data
datasets = ['Emulator', 'Desktop', 'Real-deivce']

Laplace = np.array([0.00012184, 0.00007327, 0.00006299]) * 1e3
staircase = np.array([0.00012224,0.00007334, 0.00006263]) * 1e3
staircase_intermediate = np.array([0.00046442, 0.00026188, 0.00027406]) * 1e3
laplace_delta = np.array([0.00021473, 0.00012030 , 0.0001844 ]) * 1e3

# Colors and labels taken from the style of the line plot
colors = ['#1F77B4', '#FF7F0E', '#2CA02C', '#DC143C']
labels = ['$PLM$', '$PSM$', '$PSM_i(r_b = 50, δ = 5)$', '$PLM(δ=5)$']

# Set the positions and width for the bars
pos = np.arange(len(datasets))
bar_width = 0.20

# Plotting the bars with the new style
fig, ax = plt.subplots(figsize=(10, 8))  # Increase figure size to accommodate legend

for i, (data, color, label) in enumerate(zip([Laplace, staircase, staircase_intermediate, laplace_delta], colors, labels)):
    ax.bar(pos + i * bar_width, data, bar_width, label=label, color=color)

# Adding labels and title
#ax.set_xlabel('Datasets', fontsize=28)
ax.set_ylabel('Runtime (ms)', fontsize=28)
#ax.set_title('Runtime Comparison')

# Positioning the x-ticks
ax.set_xticks(pos + 1.5 * bar_width)
ax.set_xticklabels(datasets, fontsize=28)

# Adding the legend with the modified style
# Reduce the handle length to decrease the space between the legend symbol and text
legend = ax.legend(fontsize=28, loc='upper center', bbox_to_anchor=(0.5, 1.32), fancybox=True, shadow=True, ncol=2, handlelength=1.2)

frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width

# Setting the tick parameters
ax.tick_params(axis='both', which='major', labelsize=28)

# Adjust the layout to make room for the legend outside of the plot
plt.subplots_adjust(top=0.75)
pathpng = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\figure\\png\\Runtime_devices'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')


plt.show()
