# %%
import os
import pandas as pd

# Specify the directory containing the CSV files
directory = r'C:\Users\ss6365\Desktop\location_privacy_final\tracebased\perturbed_averaged_10\laplace\0.1'

# List all CSV files in the directory
csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]

# Initialize an identifier starting from 1
identifier = 1

# Iterate over each CSV file
for file_name in csv_files:
    # Construct the full file path
    file_path = os.path.join(directory, file_name)
    
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)
    
    # Add a new column 'identifier' with all rows having the same identifier
    df['identifier'] = identifier
    
    # Save the modified DataFrame back to the same CSV file
    df.to_csv(file_path, index=False)
    
    # Increment the identifier for the next file
    identifier += 1

print('All files have been processed and updated with an identifier.')
# Out:
# All files have been processed and updated with an identifier.

# %%
import os
import pandas as pd

# Input directory containing CSV files
input_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\tracebased\perturbed_averaged_10\laplace\0.1'

# Output directory where the merged CSV file will be saved
output_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\tracebased\perturbed_averaged_10\laplace'



# # List of important columns to keep
important_columns = ['latitude', 'longitude', 'perturbed_latitude','perturbed_longitude', 'identifier']  # Replace with your column names

# # Create a list to store dataframes from individual CSV files
dataframes = []

# # Iterate through CSV files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(input_directory, filename)
        df = pd.read_csv(file_path, usecols=important_columns)
        dataframes.append(df)

# # Concatenate dataframes vertically (along rows)
merged_df = pd.concat(dataframes, ignore_index=True)

# # Output file path for the merged CSV file
output_file_path = os.path.join(output_directory, 'merged_laplace_0.1.csv')

# # Save the merged dataframe to a CSV file
merged_df.to_csv(output_file_path, index=False)

print(f"Merged CSV file saved to {output_file_path}")
# Out:
# Merged CSV file saved to C:\Users\ss6365\Desktop\location_privacy_final\tracebased\perturbed_averaged_10\laplace\merged_laplace_0.1.csv

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def process_directory(file_directory, use_alternate_columns=False, num_runs=1):
    all_files = os.listdir(file_directory)
    csv_files = [file for file in all_files if file.endswith('.csv')]
    csv_files.sort()

    trajectory_accuracy_totals = [0] * len(csv_files)

    for _ in range(num_runs):
        for idx, file_name in enumerate(csv_files):
            file_path = os.path.join(file_directory, file_name)
            data = pd.read_csv(file_path)

            # Assume each trajectory is identified by a 'trajectory_id' column
            if use_alternate_columns:
                observations = data[['reported_lat', 'reported_lon']]
            else:
                observations = data[['perturbed_latitude', 'perturbed_longitude']]
            
            secrets = data['location_id']
            trajectories = data['identifier']

            # Split data by trajectory
            trajectory_groups = data.groupby('identifier')
            correct_trajectories = 0
            total_trajectories = len(trajectory_groups)

            for trajectory_id, group in trajectory_groups:
                X = group[['perturbed_latitude', 'perturbed_longitude']]
                y = group['location_id']

                # Splitting the data from each trajectory for cross-validation or simple train-test
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

                knn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
                knn.fit(X_train, y_train)
                predicted_locations = knn.predict(X_test)

                # Evaluate accuracy per trajectory
                if accuracy_score(y_test, predicted_locations) > 0.66:  # 2 out of 3 points correctly predicted
                    correct_trajectories += 1

            trajectory_accuracy = (correct_trajectories / total_trajectories) * 100
            trajectory_accuracy_totals[idx] += trajectory_accuracy

    # Calculate the average accuracy across runs
    trajectory_accuracy_avg = [x / num_runs for x in trajectory_accuracy_totals]
    
    return trajectory_accuracy_avg

# Example usage:
file_directory = r"C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\attack1\laplace\200"
trajectory_accuracies = process_directory(file_directory)
print("Trajectory Accuracies:", trajectory_accuracies)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 58
#      56 # Example usage:
#      57 file_directory = r"C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\attack1\laplace\200"
# ---> 58 trajectory_accuracies = process_directory(file_directory)
#      59 print("Trajectory Accuracies:", trajectory_accuracies)
#
# Cell In[14], line 42, in process_directory(file_directory, use_alternate_columns, num_runs)
#      40 knn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
#      41 knn.fit(X_train, y_train)
# ---> 42 predicted_locations = knn.predict(X_test)
#      44 # Evaluate accuracy per trajectory
#      45 if accuracy_score(y_test, predicted_locations) > 0.66:  # 2 out of 3 points correctly predicted
#
# File ~\conda\lib\site-packages\sklearn\neighbors\_classification.py:234, in KNeighborsClassifier.predict(self, X)
#     218 """Predict the class labels for the provided data.
#     219
#     220 Parameters
#    (...)
#     229     Class labels for each data sample.
#     230 """
#     231 if self.weights == "uniform":
#     232     # In that case, we do not need the distances to perform
#     233     # the weighting so we do not compute them.
# --> 234     neigh_ind = self.kneighbors(X, return_distance=False)
#     235     neigh_dist = None
#     236 else:
#
# File ~\conda\lib\site-packages\sklearn\neighbors\_base.py:824, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     817 use_pairwise_distances_reductions = (
#     818     self._fit_method == "brute"
#     819     and ArgKmin.is_usable_for(
#     820         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     821     )
#     822 )
#     823 if use_pairwise_distances_reductions:
# --> 824     results = ArgKmin.compute(
#     825         X=X,
#     826         Y=self._fit_X,
#     827         k=n_neighbors,
#     828         metric=self.effective_metric_,
#     829         metric_kwargs=self.effective_metric_params_,
#     830         strategy="auto",
#     831         return_distance=return_distance,
#     832     )
#     834 elif (
#     835     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     836 ):
#     837     results = _kneighbors_from_graph(
#     838         X, n_neighbors=n_neighbors, return_distance=return_distance
#     839     )
#
# File ~\conda\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:277, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     196 """Compute the argkmin reduction.
#     197
#     198 Parameters
#    (...)
#     274 returns.
#     275 """
#     276 if X.dtype == Y.dtype == np.float64:
# --> 277     return ArgKmin64.compute(
#     278         X=X,
#     279         Y=Y,
#     280         k=k,
#     281         metric=metric,
#     282         chunk_size=chunk_size,
#     283         metric_kwargs=metric_kwargs,
#     284         strategy=strategy,
#     285         return_distance=return_distance,
#     286     )
#     288 if X.dtype == Y.dtype == np.float32:
#     289     return ArgKmin32.compute(
#     290         X=X,
#     291         Y=Y,
#    (...)
#     297         return_distance=return_distance,
#     298     )
#
# File sklearn\metrics\_pairwise_distances_reduction\_argkmin.pyx:95, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File ~\conda\lib\site-packages\sklearn\utils\fixes.py:139, in threadpool_limits(limits, user_api)
#     137     return controller.limit(limits=limits, user_api=user_api)
#     138 else:
# --> 139     return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#
# File ~\conda\lib\site-packages\threadpoolctl.py:171, in threadpool_limits.__init__(self, limits, user_api)
#     167 def __init__(self, limits=None, user_api=None):
#     168     self._limits, self._user_api, self._prefixes = \
#     169         self._check_params(limits, user_api)
# --> 171     self._original_info = self._set_threadpool_limits()
#
# File ~\conda\lib\site-packages\threadpoolctl.py:268, in threadpool_limits._set_threadpool_limits(self)
#     265 if self._limits is None:
#     266     return None
# --> 268 modules = _ThreadpoolInfo(prefixes=self._prefixes,
#     269                           user_api=self._user_api)
#     270 for module in modules:
#     271     # self._limits is a dict {key: num_threads} where key is either
#     272     # a prefix or a user_api. If a module matches both, the limit
#     273     # corresponding to the prefix is chosed.
#     274     if module.prefix in self._limits:
#
# File ~\conda\lib\site-packages\threadpoolctl.py:340, in _ThreadpoolInfo.__init__(self, user_api, prefixes, modules)
#     337     self.user_api = [] if user_api is None else user_api
#     339     self.modules = []
# --> 340     self._load_modules()
#     341     self._warn_if_incompatible_openmp()
#     342 else:
#
# File ~\conda\lib\site-packages\threadpoolctl.py:373, in _ThreadpoolInfo._load_modules(self)
#     371     self._find_modules_with_dyld()
#     372 elif sys.platform == "win32":
# --> 373     self._find_modules_with_enum_process_module_ex()
#     374 else:
#     375     self._find_modules_with_dl_iterate_phdr()
#
# File ~\conda\lib\site-packages\threadpoolctl.py:478, in _ThreadpoolInfo._find_modules_with_enum_process_module_ex(self)
#     474 n_size = DWORD()
#     475 for h_module in h_modules:
#     476
#     477     # Get the path of the current module
# --> 478     if not ps_api.GetModuleFileNameExW(
#     479             h_process, h_module, ctypes.byref(buf),
#     480             ctypes.byref(n_size)):
#     481         raise OSError("GetModuleFileNameEx failed")
#     482     filepath = buf.value
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def process_directory(file_directory, num_runs=1):
    all_files = os.listdir(file_directory)
    csv_files = [os.path.join(file_directory, file) for file in all_files if file.endswith('.csv')]
    csv_files.sort()

    # Split the list of files into training and testing subsets
    train_files, test_files = train_test_split(csv_files, test_size=0.001, random_state=42)

    # Train the model on the training set
    knn = KNeighborsClassifier(n_neighbors=10, n_jobs=-1)
    for file_path in train_files:
        data = pd.read_csv(file_path)
        X_train = data[['perturbed_latitude', 'perturbed_longitude']]
        y_train = data['location_id']
        knn.fit(X_train, y_train)

    # Evaluate on the testing set
    correctly_predicted_trajectories = 0

    for file_path in test_files:
        data = pd.read_csv(file_path)
        X_test = data[['perturbed_latitude', 'perturbed_longitude']]
        
        y_test = data['location_id']
        #print(y_test)
        predicted_locations = knn.predict(X_test)
        print(predicted_locations)
        # Calculate accuracy and check if more than 50% of the predictions are correct
        accuracy = accuracy_score(y_test, predicted_locations)
        print(accuracy)
        if accuracy >= 0.1:
            correctly_predicted_trajectories += 1

    # Calculate the percentage of correctly predicted trajectories
    total_test_files = len(test_files)
    prediction_accuracy = (correctly_predicted_trajectories / total_test_files) * 100  # Convert to percentage
    return prediction_accuracy

# Example usage
file_directory = r"C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split"
average_trajectory_accuracy = process_directory(file_directory)
print("Average Trajectory Accuracy:", average_trajectory_accuracy)
# Out:
# [187 187 187 187 187 187 187 187 187 187]
# 0.0
# [187 187 187 187 187 187 187 187 187 187]
# 1.0
# [187 187 187 187 187 187 187 187 187 187]
# 0.0
# [187 187 187 187 187 187 187 187 187 187]
# 0.0
# Average Trajectory Accuracy: 25.0

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
file_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split'

all_files = os.listdir(file_directory)
csv_files = [os.path.join(file_directory, file) for file in all_files if file.endswith('.csv')]
csv_files.sort()

    # Split the list of files into training and testing subsets
train_files, test_files = train_test_split(csv_files, test_size=0.01, random_state=42)

# %%
test_files
# Out:
# ['C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\3204.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2277.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\465.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2754.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1856.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\260.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2149.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1590.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1288.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\992.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2355.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2591.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\859.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\96.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\283.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2619.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2420.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2133.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1027.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2103.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2520.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\420.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\278.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\75.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\505.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1010.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1372.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\421.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\847.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2910.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2453.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\268.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1473.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\3363.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1282.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\1368.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2769.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\2637.csv',
#  'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\tracebased\\machine_learning\\split\\781.csv']

# %%
import pandas as pd
import os

def split_csv_by_identifier(input_directory, input_filename, output_directory):
    # Construct the full path to the input file
    input_file_path = os.path.join(input_directory, input_filename)

    # Read the CSV file
    df = pd.read_csv(input_file_path)

    # Ensure the output directory exists, if not, create it
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Split the dataframe by 'identifier' and write to separate files
    for identifier, group in df.groupby('identifier'):
        output_file_path = os.path.join(output_directory, f"{identifier}.csv")
        group.to_csv(output_file_path, index=False)
        print(f"File saved: {output_file_path}")

# Example usage:
split_csv_by_identifier(r'C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\attack1\laplace\200', r'merged_laplace_0.1_encoded_200.csv', r'C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split')
# Out:
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\1.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\2.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\4.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\5.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\6.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\7.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\8.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\9.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\10.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\11.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\12.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\13.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\14.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\15.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\16.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\17.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\18.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\19.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\20.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\21.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\22.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\23.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\24.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\25.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\26.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\27.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\28.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\29.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\30.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\31.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\32.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\33.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\34.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\35.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\36.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\37.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\38.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\39.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\40.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\41.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\42.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\43.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\44.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\45.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\46.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\47.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\48.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\49.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\50.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\51.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\52.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\53.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\54.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\55.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\56.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\57.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\58.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\59.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\60.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\61.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\62.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\63.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\64.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\65.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\66.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\67.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\68.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\69.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\70.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\71.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\72.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\73.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\74.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\75.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\76.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\77.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\78.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\79.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\80.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\81.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\82.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\83.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\84.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\85.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\86.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\87.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\88.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\89.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\90.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\91.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\92.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\93.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\94.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\95.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\96.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\97.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\98.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\99.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\100.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\101.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\102.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\103.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\104.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\105.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\106.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\107.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\108.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\109.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\110.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\111.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\112.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\113.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\114.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\115.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\116.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\117.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\118.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\119.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\120.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\121.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\122.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\123.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\124.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\125.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\126.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\127.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\128.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\129.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\130.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\131.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\132.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\133.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\134.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\135.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\136.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\137.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\138.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\139.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\140.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\141.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\142.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\143.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\144.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\145.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\146.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\147.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\148.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\149.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\150.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\151.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\152.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\153.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\154.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\155.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\156.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\157.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\158.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\159.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\160.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\161.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\162.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\163.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\164.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\165.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\166.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\167.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\168.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\169.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\170.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\171.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\172.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\173.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\174.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\175.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\176.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\177.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\178.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\179.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\180.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\181.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\182.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\183.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\184.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\185.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\186.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\187.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\188.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\189.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\190.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\191.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\192.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\193.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\194.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\195.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\196.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\197.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\198.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\199.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\200.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\201.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\202.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\203.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\204.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\205.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\206.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\207.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\208.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\209.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\210.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\211.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\212.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\213.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\214.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\215.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\216.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\217.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\218.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\219.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\220.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\221.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\222.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\223.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\224.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\225.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\226.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\227.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\228.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\229.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\230.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\231.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\232.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\233.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\234.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\235.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\236.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\237.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\238.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\239.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\240.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\241.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\242.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\243.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\244.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\245.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\246.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\247.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\248.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\249.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\250.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\251.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\252.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\253.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\254.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\255.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\256.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\257.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\258.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\259.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\260.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\261.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\262.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\263.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\264.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\265.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\266.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\267.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\268.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\269.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\270.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\271.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\272.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\273.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\274.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\275.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\276.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\277.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\278.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\279.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\280.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\281.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\282.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\283.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\284.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\285.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\286.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\287.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\288.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\289.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\290.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\291.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\292.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\293.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\294.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\295.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\296.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\297.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\298.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\299.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\300.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\301.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\302.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\303.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\304.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\305.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\306.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\307.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\308.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\309.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\310.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\311.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\312.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\313.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\314.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\315.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\316.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\317.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\318.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\319.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\320.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\321.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\322.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\323.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\324.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\325.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\326.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\327.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\328.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\329.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\330.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\331.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\332.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\333.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\334.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\335.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\336.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\337.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\338.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\339.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\340.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\341.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\342.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\343.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\344.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\345.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\346.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\347.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\348.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\349.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\350.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\351.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\352.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\353.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\354.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\355.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\356.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\357.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\358.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\359.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\360.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\361.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\362.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\363.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\364.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\365.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\366.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\367.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\368.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\369.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\370.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\371.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\372.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\373.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\374.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\375.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\376.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\377.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\378.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\379.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\380.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\381.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\382.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\383.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\384.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\385.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\386.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\387.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\388.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\389.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\390.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\391.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\392.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\393.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\394.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\395.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\396.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\397.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\398.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\399.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\400.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\401.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\402.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\403.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\404.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\405.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\406.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\407.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\408.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\409.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\410.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\411.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\412.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\413.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\414.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\415.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\416.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\417.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\418.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\419.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\420.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\421.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\422.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\423.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\424.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\425.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\426.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\427.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\428.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\429.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\430.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\431.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\432.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\433.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\434.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\435.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\436.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\437.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\438.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\439.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\440.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\441.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\442.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\443.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\444.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\445.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\446.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\447.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\448.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\449.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\450.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\451.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\452.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\453.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\454.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\455.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\456.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\457.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\458.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\459.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\460.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\461.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\462.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\463.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\464.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\465.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\466.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\467.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\468.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\469.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\470.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\471.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\472.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\473.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\474.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\475.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\476.csv
# ...
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3713.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3714.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3715.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3716.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3717.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3718.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3719.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3720.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3721.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3722.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3723.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3724.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3725.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3726.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3727.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3728.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3729.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3730.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3731.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3732.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3733.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3734.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3735.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3736.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3737.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3738.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3739.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3740.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3741.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3742.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3743.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3744.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3745.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3746.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3747.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3748.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3749.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3750.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3751.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3752.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3753.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3754.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3755.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3756.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3757.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3758.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3759.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3760.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3761.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3762.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3763.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3764.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3765.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3766.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3767.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3768.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3769.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3770.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3771.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3772.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3773.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3774.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3775.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3776.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3777.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3778.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3779.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3780.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3781.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3782.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3783.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3784.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3785.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3786.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3787.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3788.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3789.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3790.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3791.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3792.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3793.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3794.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3795.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3796.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3797.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3798.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3799.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3800.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3801.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3802.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3803.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3804.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3805.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3806.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3807.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3808.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3809.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3810.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3811.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3812.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3813.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3814.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3815.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3816.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3817.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3818.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3819.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3820.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3821.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3822.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3823.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3824.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3825.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3826.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3827.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3828.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3829.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3830.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3831.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3832.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3833.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3834.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3835.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3836.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3837.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3838.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3839.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3840.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3841.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3842.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3843.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3844.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3845.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3846.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3847.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3848.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3849.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3850.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3851.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3852.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3853.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3854.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3855.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3856.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3857.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3858.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3859.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3860.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3861.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3862.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3863.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3864.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3865.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3866.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3867.csv
# File saved: C:\Users\ss6365\Desktop\location_privacy_final\tracebased\machine_learning\split\3868.csv

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical

def load_and_preprocess_data(file_directory):
    # Load all CSV files and concatenate into a single DataFrame
    files = [os.path.join(file_directory, f) for f in os.listdir(file_directory) if f.endswith('.csv')]
    data_frames = [pd.read_csv(f) for f in files]
    data = pd.concat(data_frames, ignore_index=True)
    
    # Assuming 'perturbed_latitude' and 'perturbed_longitude' are the inputs and 'location_id' is the target
    X = data[['perturbed_latitude', 'perturbed_longitude']].values
    y = data['location_id'].values
    
    # Standardize the features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Reshape data into sequences (example: sequences of 10 points)
    seq_length = 20
    X_seq = []
    y_seq = []
    for i in range(len(data) - seq_length + 1):
        X_seq.append(X_scaled[i:i + seq_length])
        y_seq.append(y[i + seq_length - 1])  # Label for the last item in the sequence
    
    X_seq = np.array(X_seq)
    y_seq = np.array(y_seq)
    
    # One-hot encode the labels
    y_seq_encoded = to_categorical(y_seq)
    
    return X_seq, y_seq_encoded

def build_lstm_model(input_shape, num_classes):
    model = Sequential([
        LSTM(100, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(100),
        Dropout(0.2),
        Dense(100, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def main():
    file_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected\machine_learning\attack20\laplace'  # Update the path to your dataset
    X_seq, y_seq_encoded = load_and_preprocess_data(file_directory)
    
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq_encoded, test_size=0.2, random_state=42)
    
    # Build the LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = y_train.shape[1]
    model = build_lstm_model(input_shape, num_classes)
    
    # Train the model
    model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
    
    # Evaluate the model
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f'Test Accuracy: {test_acc*100:.2f}%')

if __name__ == '__main__':
    main()
# Out:
# Epoch 1/5
# 771/771 [==============================] - 105s 131ms/step - loss: 5.4720 - accuracy: 0.1108 - val_loss: 4.5013 - val_accuracy: 0.1344
# Epoch 2/5
# 771/771 [==============================] - 100s 130ms/step - loss: 3.7273 - accuracy: 0.2178 - val_loss: 3.1193 - val_accuracy: 0.2740
# Epoch 3/5
# 771/771 [==============================] - 100s 130ms/step - loss: 2.8620 - accuracy: 0.3033 - val_loss: 2.5963 - val_accuracy: 0.3481
# Epoch 4/5
# 771/771 [==============================] - 101s 131ms/step - loss: 2.4474 - accuracy: 0.3619 - val_loss: 2.3068 - val_accuracy: 0.4174
# Epoch 5/5
# 771/771 [==============================] - 101s 131ms/step - loss: 2.1704 - accuracy: 0.4075 - val_loss: 2.0550 - val_accuracy: 0.4563
# 241/241 [==============================] - 6s 26ms/step - loss: 2.0798 - accuracy: 0.4423
# Test Accuracy: 44.23%

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical

def load_and_preprocess_data(file_directory):
    # Load all CSV files and concatenate into a single DataFrame
    files = [os.path.join(file_directory, f) for f in os.listdir(file_directory) if f.endswith('.csv')]
    data_frames = [pd.read_csv(f) for f in files]
    data = pd.concat(data_frames, ignore_index=True)
    
    # Assuming 'perturbed_latitude' and 'perturbed_longitude' are the inputs and 'location_id' is the target
    X = data[['perturbed_latitude', 'perturbed_longitude']].values
    y = data['location_id'].values
    
    # Standardize the features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Reshape data into sequences (example: sequences of 10 points)
    seq_length = 30
    X_seq = []
    y_seq = []
    for i in range(len(data) - seq_length + 1):
        X_seq.append(X_scaled[i:i + seq_length])
        y_seq.append(y[i + seq_length - 1])  # Label for the last item in the sequence
    
    X_seq = np.array(X_seq)
    y_seq = np.array(y_seq)
    
    # One-hot encode the labels
    y_seq_encoded = to_categorical(y_seq)
    
    return X_seq, y_seq_encoded

def build_lstm_model(input_shape, num_classes):
    model = Sequential([
        LSTM(50, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(50),
        Dropout(0.2),
        Dense(100, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def main():
    file_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected\machine_learning\attack30\laplace'  # Update the path to your dataset
    X_seq, y_seq_encoded = load_and_preprocess_data(file_directory)
    
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq_encoded, test_size=0.2, random_state=42)
    
    # Build the LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = y_train.shape[1]
    model = build_lstm_model(input_shape, num_classes)
    
    # Train the model
    model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
    
    # Evaluate the model
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f'Test Accuracy: {test_acc*100:.2f}%')

if __name__ == '__main__':
    main()
# Out:
# Epoch 1/5
# 770/770 [==============================] - 55s 68ms/step - loss: 5.0723 - accuracy: 0.1365 - val_loss: 3.6537 - val_accuracy: 0.2010
# Epoch 2/5
# 770/770 [==============================] - 46s 59ms/step - loss: 3.2118 - accuracy: 0.2542 - val_loss: 2.8091 - val_accuracy: 0.3274
# Epoch 3/5
# 770/770 [==============================] - 46s 59ms/step - loss: 2.6724 - accuracy: 0.3284 - val_loss: 2.4251 - val_accuracy: 0.4006
# Epoch 4/5
# 770/770 [==============================] - 47s 60ms/step - loss: 2.3765 - accuracy: 0.3708 - val_loss: 2.1784 - val_accuracy: 0.4581
# Epoch 5/5
# 770/770 [==============================] - 45s 58ms/step - loss: 2.1685 - accuracy: 0.4055 - val_loss: 1.9874 - val_accuracy: 0.4782
# 241/241 [==============================] - 4s 18ms/step - loss: 2.0055 - accuracy: 0.4739
# Test Accuracy: 47.39%

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical

def load_and_preprocess_data(file_directory):
    # Load all CSV files and concatenate into a single DataFrame
    files = [os.path.join(file_directory, f) for f in os.listdir(file_directory) if f.endswith('.csv')]
    data_frames = [pd.read_csv(f) for f in files]
    data = pd.concat(data_frames, ignore_index=True)
    
    # Assuming 'perturbed_latitude' and 'perturbed_longitude' are the inputs and 'location_id' is the target
    X = data[['perturbed_latitude', 'perturbed_longitude']].values
    y = data['location_id'].values
    
    # Standardize the features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Reshape data into sequences (example: sequences of 10 points)
    seq_length = 10
    X_seq = []
    y_seq = []
    for i in range(len(data) - seq_length + 1):
        X_seq.append(X_scaled[i:i + seq_length])
        y_seq.append(y[i + seq_length - 1])  # Label for the last item in the sequence
    
    X_seq = np.array(X_seq)
    y_seq = np.array(y_seq)
    
    # One-hot encode the labels
    y_seq_encoded = to_categorical(y_seq)
    
    return X_seq, y_seq_encoded

def build_lstm_model(input_shape, num_classes):
    model = Sequential([
        LSTM(100, return_sequences=True, input_shape=input_shape),
        Dropout(0.2),
        LSTM(50),
        Dropout(0.2),
        Dense(100, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def main():
    file_directory = r'C:\Users\ss6365\Desktop\location_privacy_final\collected\machine_learning\attack10\laplace'  # Update the path to your dataset
    X_seq, y_seq_encoded = load_and_preprocess_data(file_directory)
    
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq_encoded, test_size=0.2, random_state=42)
    
    # Build the LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = y_train.shape[1]
    model = build_lstm_model(input_shape, num_classes)
    
    # Train the model
    model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
    
    # Evaluate the model
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print(f'Test Accuracy: {test_acc*100:.2f}%')

if __name__ == '__main__':
    main()
# Out:
# Epoch 1/5
# 774/774 [==============================] - 61s 75ms/step - loss: 5.1989 - accuracy: 0.1379 - val_loss: 3.8834 - val_accuracy: 0.2038
# Epoch 2/5
# 774/774 [==============================] - 79s 102ms/step - loss: 3.3486 - accuracy: 0.2394 - val_loss: 2.9602 - val_accuracy: 0.2867
# Epoch 3/5
# 774/774 [==============================] - 56s 72ms/step - loss: 2.7491 - accuracy: 0.3131 - val_loss: 2.5318 - val_accuracy: 0.3788
# Epoch 4/5
# 774/774 [==============================] - 56s 72ms/step - loss: 2.4007 - accuracy: 0.3594 - val_loss: 2.3014 - val_accuracy: 0.4074
# Epoch 5/5
# 774/774 [==============================] - 55s 72ms/step - loss: 2.1760 - accuracy: 0.3912 - val_loss: 2.0842 - val_accuracy: 0.4190
# 242/242 [==============================] - 4s 18ms/step - loss: 2.0859 - accuracy: 0.4149
# Test Accuracy: 41.49%
