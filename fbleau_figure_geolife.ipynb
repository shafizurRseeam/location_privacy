# %%
import numpy as np
import pandas as pd 

import os
import glob
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import numpy as np

# %%
# df_laplace_ln_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_collected_ln_300.csv')
# df_staircase_ln_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_staircase_collected_ln_300.csv')
# df_laplace_delta_ln_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_delta_5_collected_ln_300.csv')
# df_our_ln_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_our_bl_50_delta_5_collected_ln_300.csv')

# df_laplace_log_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_collected_log10_300.csv')
# df_staircase_log_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_staircase_collected_log10_300.csv')
# df_laplace_delta_log_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_delta_5_collected_log10_300.csv')
# df_our_log_300_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_our_bl_50_delta_5_collected_log10_300.csv')

# df_laplace_ln_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_collected_ln_100.csv')
# df_staircase_ln_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_staircase_collected_ln_100.csv')
# df_laplace_delta_ln_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_delta_5_collected_ln_100.csv')
# df_our_ln_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_our_bl_50_delta_5_collected_ln_100.csv')

# df_laplace_log_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_collected_log10_100.csv')
# df_staircase_log_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_staircase_collected_log10_100.csv')
# df_laplace_delta_log_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_delta_5_collected_log10_100.csv')
# df_our_log_100_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_our_bl_50_delta_5_collected_log10_100.csv')


df_laplace_ln_200_geolife = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_laplace_ln_200.csv')
df_staircase_ln_200_geolife = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_staircase_ln_200.csv')
# df_laplace_delta_ln_200_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_delta_5_collected_ln_200.csv')
df_our_ln_200_geolife = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_our_bl_50_delta_5_ln_200.csv')

# df_laplace_log_200_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_collected_log10_200.csv')
# df_staircase_log_200_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_staircase_collected_log10_200.csv')
# df_laplace_delta_log_200_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_laplace_delta_5_collected_log10_200.csv')
# df_our_log_200_collected = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\collected\fbleau\fbleau_results_our_bl_50_delta_5_collected_log10_200.csv')

# %%
# # Example data (assuming you have these data frames ready)
# epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# # Define lines with linestyle added
# line1 = {'x': epsilon_values, 'y': df_laplace_ln_300_col['Bayes security measure'], 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line2 = {'x': epsilon_values, 'y': df_staircase_ln_300_collected['Bayes security measure'], 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line3 = {'x': epsilon_values, 'y': df_our_ln_300_collected['Bayes security measure'], 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line4 = {'x': epsilon_values, 'y': df_laplace_delta_ln_300_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

# plt.figure(figsize=(10, 6))

# # Plot each line with improved settings
# for line in [line1, line2, line3, line4]:
#     plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# # Labels for axes
# plt.xlabel('$\epsilon$', fontsize=36)
# plt.ylabel('Bayes Risk', fontsize=28)

# # Log scale for x-axis and setting specific ticks and labels
# plt.xscale('log')
# plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
# plt.tick_params(axis='both', which='major', labelsize=28)

# # Adding a grid, legend, and ensuring layout is tight for best appearance
# #plt.grid(True)
# plt.legend(fontsize=28, frameon=True, loc='best')
# plt.tight_layout()
# plt.title('Collected 300 (ln)')
# # Uncomment the following lines to save the plot if needed
# # plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# # plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# # Display the plot
# plt.show()

# %%
# # Example data (assuming you have these data frames ready)
# epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# # Define lines with linestyle added
# line1 = {'x': epsilon_values, 'y': df_laplace_log_300_collected['Bayes security measure'], 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line2 = {'x': epsilon_values, 'y': df_staircase_log_300_collected['Bayes security measure'], 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line3 = {'x': epsilon_values, 'y': df_laplace_delta_log_300_collected['Bayes security measure'], 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line4 = {'x': epsilon_values, 'y': df_our_log_300_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

# plt.figure(figsize=(10, 6))

# # Plot each line with improved settings
# for line in [line1, line2, line3, line4]:
#     plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# # Labels for axes
# plt.xlabel('$\epsilon$', fontsize=36)
# plt.ylabel('Bayes Risk', fontsize=28)

# # Log scale for x-axis and setting specific ticks and labels
# plt.xscale('log')
# plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
# plt.tick_params(axis='both', which='major', labelsize=28)

# # Adding a grid, legend, and ensuring layout is tight for best appearance
# #plt.grid(True)
# plt.legend(fontsize=28, frameon=True, loc='best')
# plt.tight_layout()
# plt.title('Collected 300 (log 10)')
# # Uncomment the following lines to save the plot if needed
# # plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# # plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# # Display the plot
# plt.show()

# %%
# Example data (assuming you have these data frames ready)
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': df_laplace_ln_200_geolife['Bayes security measure'], 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': df_staircase_ln_200_geolife['Bayes security measure'], 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': df_our_ln_200_geolife['Bayes security measure'], 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_laplace_delta_ln_200_geolife['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$\epsilon$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels
plt.xscale('log')
plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
plt.legend(fontsize=28, frameon=True,shadow=True, loc='best').get_frame().set_edgecolor('black')

plt.tight_layout()

# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

pathpng = r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\figure\png\bayes_point_ln_200'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')

pathsvg = r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\figure\svg\bayes_point_ln_200'

plt.savefig(pathsvg, format='svg', bbox_inches='tight')
# Display the plot
plt.show()

# %%
df_our_5_ln_200_uci = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_10_ln_200_uci = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_our_bl_50_delta_10_ln_200.csv')
#df_laplace_delta_ln_200_uci = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\uci\fbleau\fbleau_results_laplace_uci_5_collected_ln_200.csv')
df_our_15_ln_200_uci = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_our_bl_50_delta_15_ln_200.csv')
df_our_20_ln_200_uci = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau\fbleau_results_our_bl_50_delta_20_ln_200.csv')

# %%
# Example data (assuming you have these data frames ready)
epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# Base label for consistency
base_label = 'PSM-I$(\delta={})$'

# Define lines with linestyle added
lines = [
    {'x': epsilon_values, 'y': df_our_5_ln_200_uci['Bayes security measure'], 'delta': 5, 'color': '#1F77B4', 'marker': 'D'},
    {'x': epsilon_values, 'y': df_our_10_ln_200_uci['Bayes security measure'], 'delta': 10, 'color': '#FF7F0E', 'marker': 'o'},
    {'x': epsilon_values, 'y': df_our_15_ln_200_uci['Bayes security measure'], 'delta': 15, 'color': '#2CA02C', 'marker': 'X'},
    {'x': epsilon_values, 'y': df_our_20_ln_200_uci['Bayes security measure'], 'delta': 20, 'color': '#DC143C', 'marker': '*'}
]

plt.figure(figsize=(10, 6))

# Plot each line
for line in lines:
    label = base_label.format(line['delta'])
    plt.plot(line['x'], line['y'], label=label, color=line['color'], marker=line['marker'], linestyle='-', linewidth=2, markersize=12)

# Labels for axes
plt.xlabel('$\epsilon$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels
plt.xscale('log')
plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
plt.legend(fontsize=28, frameon=True, shadow=True, loc='best').get_frame().set_edgecolor('black')

plt.tight_layout()
legend = plt.legend(fontsize=28, loc='upper center', bbox_to_anchor=(0.5, 1.35), shadow=True, ncol=2, handlelength=1.5)
# Adjust the legend's frame appearance
frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width

pathpng = r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\figure\png\bayes_point_ln_200_delta_variation'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')

pathsvg = r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\figure\svg\bayes_point_ln_200_delta_variation'

plt.savefig(pathsvg, format='svg', bbox_inches='tight')
# Display the plot
plt.show()

# %%
# # Example data (assuming you have these data frames ready)
# epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# # Define lines with linestyle added
# line1 = {'x': epsilon_values, 'y': df_laplace_log_200_collected['Bayes security measure'], 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line2 = {'x': epsilon_values, 'y': df_staircase_log_200_collected['Bayes security measure'], 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line3 = {'x': epsilon_values, 'y': df_laplace_delta_log_200_collected['Bayes security measure'], 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line4 = {'x': epsilon_values, 'y': df_our_log_200_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

# plt.figure(figsize=(10, 6))

# # Plot each line with improved settings
# for line in [line1, line2, line3, line4]:
#     plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# # Labels for axes
# plt.xlabel('$\epsilon$', fontsize=36)
# plt.ylabel('Bayes Risk', fontsize=28)

# # Log scale for x-axis and setting specific ticks and labels
# plt.xscale('log')
# plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
# plt.tick_params(axis='both', which='major', labelsize=28)

# # Adding a grid, legend, and ensuring layout is tight for best appearance
# #plt.grid(True)
# plt.legend(fontsize=28, frameon=True, loc='best')
# plt.tight_layout()
# plt.title('Collected 200 (log 10)')
# # Uncomment the following lines to save the plot if needed
# # plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# # plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# # Display the plot
# plt.show()

# %%
# # Example data (assuming you have these data frames ready)
# epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# # Define lines with linestyle added
# line1 = {'x': epsilon_values, 'y': df_laplace_ln_100_collected['Bayes security measure'], 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line2 = {'x': epsilon_values, 'y': df_staircase_ln_100_collected['Bayes security measure'], 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line3 = {'x': epsilon_values, 'y': df_our_ln_100_collected['Bayes security measure'], 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line4 = {'x': epsilon_values, 'y': df_laplace_delta_ln_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

# plt.figure(figsize=(10, 6))

# # Plot each line with improved settings
# for line in [line1, line2, line3, line4]:
#     plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# # Labels for axes
# plt.xlabel('$\epsilon$', fontsize=36)
# plt.ylabel('Bayes Risk', fontsize=28)

# # Log scale for x-axis and setting specific ticks and labels
# plt.xscale('log')
# plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
# plt.tick_params(axis='both', which='major', labelsize=28)

# # Adding a grid, legend, and ensuring layout is tight for best appearance
# #plt.grid(True)
# plt.legend(fontsize=28, frameon=True, loc='best')
# plt.tight_layout()
# plt.title('Collected 100 (ln)')
# # Uncomment the following lines to save the plot if needed
# # plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# # plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# # Display the plot
# plt.show()

# %%
# # Example data (assuming you have these data frames ready)
# epsilon_values = [0.1, 0.2, 0.5, 1, 2, 3, 4, 5]

# # Define lines with linestyle added
# line1 = {'x': epsilon_values, 'y': df_laplace_log_100_collected['Bayes security measure'], 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line2 = {'x': epsilon_values, 'y': df_staircase_log_100_collected['Bayes security measure'], 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line3 = {'x': epsilon_values, 'y': df_laplace_delta_log_100_collected['Bayes security measure'], 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
# line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

# plt.figure(figsize=(10, 6))

# # Plot each line with improved settings
# for line in [line1, line2, line3, line4]:
#     plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# # Labels for axes
# plt.xlabel('$\epsilon$', fontsize=36)
# plt.ylabel('Bayes Risk', fontsize=28)

# # Log scale for x-axis and setting specific ticks and labels
# plt.xscale('log')
# plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
# plt.tick_params(axis='both', which='major', labelsize=28)

# # Adding a grid, legend, and ensuring layout is tight for best appearance
# #plt.grid(True)
# plt.legend(fontsize=28, frameon=True, loc='best')
# plt.tight_layout()
# plt.title('Collected 100 (log 10)')
# # Uncomment the following lines to save the plot if needed
# # plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# # plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# # Display the plot
# plt.show()

# %%
################### TRACE

# %%
df_laplace_ln_200_10
# Out:
#    Minimum estimate  Multiplicative Leakage  Additive Leakage  \
# 0          0.251167               44.334963          0.731943
# 1          0.188478               48.046455          0.794631
# 2          0.186950               48.136919          0.796159
#
#    Bayes security measure  Min-entropy Leakage
# 0                0.255482             5.470373
# 1                0.191716             5.586358
# 2                0.190162             5.589072

# %%
df_laplace_ln_200_10 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_10\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_20 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_20\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_30 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_30\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_40 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_40\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_50 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_50\fbleau_results_laplace_ln_200.csv')

# %%
laplace = [df_laplace_ln_200_10['Bayes security measure'].iloc[2], df_laplace_ln_200_20['Bayes security measure'].iloc[2], df_laplace_ln_200_30['Bayes security measure'].iloc[2], df_laplace_ln_200_40['Bayes security measure'].iloc[2], df_laplace_ln_200_50['Bayes security measure'].iloc[2]]
laplace
# Out:
# [0.1901621439973116,
#  0.1907075873827791,
#  0.188907996560619,
#  0.1930780042164441,
#  0.1949114847433502]

# %%
df_staircase_ln_200_10 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_10\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_20 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_20\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_30 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_30\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_40 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_40\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_50 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_50\fbleau_results_staircase_ln_200.csv')

# %%
staircase = [df_staircase_ln_200_10['Bayes security measure'].iloc[2], df_staircase_ln_200_20['Bayes security measure'].iloc[2], df_staircase_ln_200_30['Bayes security measure'].iloc[2], df_staircase_ln_200_40['Bayes security measure'].iloc[2], df_staircase_ln_200_50['Bayes security measure'].iloc[2]]
staircase
# Out:
# [0.1901621439973116,
#  0.1904944586530264,
#  0.1879621668099742,
#  0.1932097680955727,
#  0.1942442843163419]

# %%
df_our_ln_200_10 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_10\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_ln_200_20 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_20\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_ln_200_30 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_30\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_ln_200_40 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_40\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_ln_200_50 = pd.read_csv(r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\fbleau_50\fbleau_results_our_bl_50_delta_5_ln_200.csv')

# %%
our = [df_our_ln_200_10['Bayes security measure'].iloc[2], df_our_ln_200_20['Bayes security measure'].iloc[2], df_our_ln_200_30['Bayes security measure'].iloc[2], df_our_ln_200_40['Bayes security measure'].iloc[2], df_our_ln_200_50['Bayes security measure'].iloc[2]]
our
# Out:
# [0.2086868856590775,
#  0.2121057118499573,
#  0.2095442820292347,
#  0.2150825720309205,
#  0.2161284583222133]

# %%
# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
#plt.title('Collected 100 (log 10)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
#   ln, 100 ###################### 

df_laplace_ln_100_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_ln_100.csv')

df_staircase_ln_100_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_ln_100.csv')
df_staircase_ln_100_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_ln_100.csv')
df_staircase_ln_100_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_ln_100.csv')
df_staircase_ln_100_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_ln_100.csv')
df_staircase_ln_100_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_ln_100.csv')

df_our_bl_50_delta_5_ln_100_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_ln_100.csv')
df_our_bl_50_delta_5_ln_100_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_ln_100.csv')
df_our_bl_50_delta_5_ln_100_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_ln_100.csv')
df_our_bl_50_delta_5_ln_100_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_ln_100.csv')
df_our_bl_50_delta_5_ln_100_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_ln_100.csv')

df_laplace_ln_100_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_ln_100.csv')
df_laplace_ln_100_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_ln_100.csv')



#   ln, 200 ###################### 

df_laplace_ln_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_ln_200.csv')

df_staircase_ln_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_ln_200.csv')
df_staircase_ln_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_ln_200.csv')

df_our_bl_50_delta_5_ln_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_bl_50_delta_5_ln_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_bl_50_delta_5_ln_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_bl_50_delta_5_ln_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_ln_200.csv')
df_our_bl_50_delta_5_ln_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_ln_200.csv')

df_laplace_ln_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_ln_200.csv')
df_laplace_ln_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_ln_200.csv')






#   ln, 300 ###################### 

df_laplace_ln_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_ln_300.csv')
df_laplace_ln_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_ln_300.csv')
df_laplace_ln_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_ln_300.csv')
df_laplace_ln_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_ln_300.csv')
df_laplace_ln_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_ln_300.csv')

df_staircase_ln_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_ln_300.csv')
df_staircase_ln_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_ln_300.csv')
df_staircase_ln_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_ln_300.csv')
df_staircase_ln_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_ln_300.csv')
df_staircase_ln_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_ln_300.csv')

df_our_bl_50_delta_5_ln_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_ln_300.csv')
df_our_bl_50_delta_5_ln_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_ln_300.csv')
df_our_bl_50_delta_5_ln_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_ln_300.csv')
df_our_bl_50_delta_5_ln_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_ln_300.csv')
df_our_bl_50_delta_5_ln_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_ln_300.csv')

df_laplace_ln_400_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_ln_400.csv')
df_laplace_ln_400_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_ln_400.csv')
df_laplace_ln_400_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_ln_400.csv')
df_laplace_ln_400_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_ln_400.csv')
df_laplace_ln_400_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_ln_400.csv')




#   ln, 400 ###################### 
df_staircase_ln_400_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_ln_400.csv')
df_staircase_ln_400_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_ln_400.csv')
df_staircase_ln_400_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_ln_400.csv')
df_staircase_ln_400_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_ln_400.csv')
df_staircase_ln_400_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_ln_400.csv')

df_our_bl_50_delta_5_ln_400_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_ln_400.csv')
df_our_bl_50_delta_5_ln_400_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_ln_400.csv')
df_our_bl_50_delta_5_ln_400_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_ln_400.csv')
df_our_bl_50_delta_5_ln_400_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_ln_400.csv')
df_our_bl_50_delta_5_ln_400_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_ln_400.csv')



#   log, 200 ###################### 
df_laplace_log10_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_log10_200.csv')

df_staircase_log10_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_log10_200.csv')

df_our_bl_50_delta_5_log10_200_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_200_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_200_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_200_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_200_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_log10_200.csv')

#   log, 300 ###################### 
df_laplace_log10_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_log10_200.csv')

df_staircase_log10_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_log10_200.csv')

df_our_bl_50_delta_5_log10_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_log10_200.csv')


#   log, 400 ###################### 
df_laplace_log10_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_laplace_log10_200.csv')
df_laplace_log10_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_laplace_log10_200.csv')

df_staircase_log10_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_staircase_log10_200.csv')
df_staircase_log10_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_staircase_log10_200.csv')

df_our_bl_50_delta_5_log10_300_10 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_10\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_20 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_20\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_30 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_30\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_40 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_40\\fbleau_results_our_bl_50_delta_5_log10_200.csv')
df_our_bl_50_delta_5_log10_300_50 = pd.read_csv(r'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\geolife\\fbleau_50\\fbleau_results_our_bl_50_delta_5_log10_200.csv')

# %%
laplace = [df_laplace_ln_100_10['Bayes security measure'].iloc[1], df_laplace_ln_100_20['Bayes security measure'].iloc[1], df_laplace_ln_100_30['Bayes security measure'].iloc[1], df_laplace_ln_100_40['Bayes security measure'].iloc[1], df_laplace_ln_100_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_ln_100_10['Bayes security measure'].iloc[1], df_staircase_ln_100_20['Bayes security measure'].iloc[1], df_staircase_ln_100_30['Bayes security measure'].iloc[1], df_staircase_ln_100_40['Bayes security measure'].iloc[1], df_staircase_ln_100_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_ln_100_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_100_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_100_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_100_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_100_50['Bayes security measure'].iloc[1]]


# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
plt.title('geolife 100 (ln)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
laplace = [df_laplace_ln_200_10['Bayes security measure'].iloc[1], df_laplace_ln_200_20['Bayes security measure'].iloc[1], df_laplace_ln_200_30['Bayes security measure'].iloc[1], df_laplace_ln_200_40['Bayes security measure'].iloc[1], df_laplace_ln_200_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_ln_200_10['Bayes security measure'].iloc[1], df_staircase_ln_200_20['Bayes security measure'].iloc[1], df_staircase_ln_200_30['Bayes security measure'].iloc[1], df_staircase_ln_200_40['Bayes security measure'].iloc[1], df_staircase_ln_200_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_ln_200_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_200_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_200_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_200_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_200_50['Bayes security measure'].iloc[1]]


# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
plt.title('geolife 200 (ln)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
laplace = [df_laplace_ln_300_10['Bayes security measure'].iloc[1], df_laplace_ln_300_20['Bayes security measure'].iloc[1], df_laplace_ln_300_30['Bayes security measure'].iloc[1], df_laplace_ln_300_40['Bayes security measure'].iloc[1], df_laplace_ln_300_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_ln_300_10['Bayes security measure'].iloc[1], df_staircase_ln_300_20['Bayes security measure'].iloc[1], df_staircase_ln_300_30['Bayes security measure'].iloc[1], df_staircase_ln_300_40['Bayes security measure'].iloc[1], df_staircase_ln_300_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_ln_300_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_300_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_300_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_300_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_300_50['Bayes security measure'].iloc[1]]


# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('Trajectory Length', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)
# Modify the legend to match the desired style
legend = plt.legend(fontsize=28, loc='upper center', bbox_to_anchor=(0.5, 1.35),  shadow=True, ncol=2, handlelength=1.5)

# Adjust the legend's frame appearance
frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color to match the bar plot example
frame.set_linewidth(1)  # Set the border width



frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width


# Setting the tick parameters
# Adjust layout to make room for the legend outside of the plot

# Display the plot with the modified legend
# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)


pathpng = r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\figure\png\bayes_point_ln_300_trace'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')

pathsvg = r'C:\Users\ss6365\Desktop\location_privacy_final\geolife\figure\svg\bayes_point_ln_300_trace'

plt.savefig(pathsvg, format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
laplace = [df_laplace_ln_400_10['Bayes security measure'].iloc[1], df_laplace_ln_400_20['Bayes security measure'].iloc[1], df_laplace_ln_400_30['Bayes security measure'].iloc[1], df_laplace_ln_400_40['Bayes security measure'].iloc[1], df_laplace_ln_400_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_ln_400_10['Bayes security measure'].iloc[1], df_staircase_ln_400_20['Bayes security measure'].iloc[1], df_staircase_ln_400_30['Bayes security measure'].iloc[1], df_staircase_ln_400_40['Bayes security measure'].iloc[1], df_staircase_ln_400_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_ln_400_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_400_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_400_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_400_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_ln_400_50['Bayes security measure'].iloc[1]]

# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
plt.title('geolife 400 (ln)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
laplace = [df_laplace_log10_200_10['Bayes security measure'].iloc[1], df_laplace_log10_200_30['Bayes security measure'].iloc[1], df_laplace_log10_200_40['Bayes security measure'].iloc[1], df_laplace_log10_200_50['Bayes security measure'].iloc[1], df_laplace_log10_200_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_log10_200_10['Bayes security measure'].iloc[1], df_staircase_log10_200_20['Bayes security measure'].iloc[1], df_staircase_log10_200_30['Bayes security measure'].iloc[1], df_staircase_log10_200_40['Bayes security measure'].iloc[1], df_staircase_log10_200_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_log10_200_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_200_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_200_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_200_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_200_50['Bayes security measure'].iloc[1]]


# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
plt.title('geolife 200 (log)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
laplace = [df_laplace_log10_300_10['Bayes security measure'].iloc[1], df_laplace_log10_300_30['Bayes security measure'].iloc[1], df_laplace_log10_300_40['Bayes security measure'].iloc[1], df_laplace_log10_300_50['Bayes security measure'].iloc[1], df_laplace_log10_300_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_log10_300_10['Bayes security measure'].iloc[1], df_staircase_log10_300_20['Bayes security measure'].iloc[1], df_staircase_log10_300_30['Bayes security measure'].iloc[1], df_staircase_log10_300_40['Bayes security measure'].iloc[1], df_staircase_log10_300_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_log10_300_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_300_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_300_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_300_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_300_50['Bayes security measure'].iloc[1]]


# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
plt.title('geolife 300 (log)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
plt.show()

# %%
laplace = [df_laplace_log10_400_10['Bayes security measure'].iloc[1], df_laplace_log10_400_30['Bayes security measure'].iloc[1], df_laplace_log10_400_40['Bayes security measure'].iloc[1], df_laplace_log10_400_50['Bayes security measure'].iloc[1], df_laplace_log10_400_50['Bayes security measure'].iloc[1]]
staircase = [df_staircase_log10_400_10['Bayes security measure'].iloc[1], df_staircase_log10_400_20['Bayes security measure'].iloc[1], df_staircase_log10_400_30['Bayes security measure'].iloc[1], df_staircase_log10_400_40['Bayes security measure'].iloc[1], df_staircase_log10_400_50['Bayes security measure'].iloc[1]]
our = [df_our_bl_50_delta_5_log10_400_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_50['Bayes security measure'].iloc[1]]


# Example data (assuming you have these data frames ready)
epsilon_values = [10, 20, 30, 40,50]

# Define lines with linestyle added
line1 = {'x': epsilon_values, 'y': laplace, 'label': r'PLM', 'color': '#1F77B4', 'marker': 'D', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line2 = {'x': epsilon_values, 'y': staircase, 'label': 'PSM', 'color': '#FF7F0E', 'marker': 'o', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
line3 = {'x': epsilon_values, 'y': our, 'label': 'PSM-I$(r_b=50, \delta=5)$', 'color': '#2CA02C', 'marker': 'X', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}
#line4 = {'x': epsilon_values, 'y': df_our_log_100_collected['Bayes security measure'], 'label': r'PLM$_{\delta}\,(\delta=5)$', 'color': '#DC143C', 'marker': '*', 'linewidth': 2, 'markersize': 12, 'linestyle': '-'}

plt.figure(figsize=(10, 6))

# Plot each line with improved settings
for line in [line1, line2, line3]:
    plt.plot(line['x'], line['y'], label=line['label'], color=line['color'], marker=line['marker'], linestyle=line['linestyle'], linewidth=line['linewidth'], markersize=line['markersize'])

# Labels for axes
plt.xlabel('$Trajectory Length$', fontsize=36)
plt.ylabel('Bayes Risk', fontsize=28)

# Log scale for x-axis and setting specific ticks and labels

plt.xticks(epsilon_values, labels=[str(val) for val in epsilon_values])
plt.tick_params(axis='both', which='major', labelsize=28)

# Adding a grid, legend, and ensuring layout is tight for best appearance
#plt.grid(True)
plt.legend(fontsize=28, frameon=True, loc='best')
plt.tight_layout()
plt.title('geolife 400 (log)')
# Uncomment the following lines to save the plot if needed
# plt.savefig('/path/to/your/directory/filename.png', dpi=300, bbox_inches='tight')
# plt.savefig('/path/to/your/directory/filename.svg', format='svg', bbox_inches='tight')

# Display the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 laplace = [df_laplace_log10_400_10['Bayes security measure'].iloc[1], df_laplace_log10_400_30['Bayes security measure'].iloc[1], df_laplace_log10_400_40['Bayes security measure'].iloc[1], df_laplace_log10_400_50['Bayes security measure'].iloc[1], df_laplace_log10_400_50['Bayes security measure'].iloc[1]]
#       2 staircase = [df_staircase_log10_400_10['Bayes security measure'].iloc[1], df_staircase_log10_400_20['Bayes security measure'].iloc[1], df_staircase_log10_400_30['Bayes security measure'].iloc[1], df_staircase_log10_400_40['Bayes security measure'].iloc[1], df_staircase_log10_400_50['Bayes security measure'].iloc[1]]
#       3 our = [df_our_bl_50_delta_5_log10_400_10['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_20['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_30['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_40['Bayes security measure'].iloc[1], df_our_bl_50_delta_5_log10_400_50['Bayes security measure'].iloc[1]]
#
# NameError: name 'df_laplace_log10_400_10' is not defined
