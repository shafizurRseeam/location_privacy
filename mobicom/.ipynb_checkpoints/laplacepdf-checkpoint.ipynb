# %%
import os
import pandas as pd
import numpy as np
import random
import scipy
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity

# %%
def laplace_noise(epsilon):

    theta = np.random.uniform(0, 2*np.pi)
    p = random.random()
    r = -1 / epsilon * (scipy.special.lambertw((p - 1) / np.e, k=-1, tol=1e-8).real + 1)
    x, y = r * np.cos(theta), r * np.sin(theta)

    return r

# %%
def generate_rs(epsilon, num_samples):
    return [laplace_noise(epsilon) for _ in range(num_samples)]

# Parameters
epsilon = 1  # Privacy parameter
num_samples =500000  # Number of r values to generate

# Generate r values
rs = generate_rs(epsilon, num_samples)

# Plotting the histogram of r values
plt.hist(rs, bins=100, density=True, alpha=0.6, color='g')
plt.title('Histogram of Generated $r$ Values')
plt.xlabel('$r$ values')
plt.ylabel('Density')
plt.show()

# %%
rs_array = np.array(rs).reshape(-1, 1)  # Reshape to 2D array for sklearn

# Fit Kernel Density Estimation
kde = KernelDensity(kernel='gaussian', bandwidth=0.1)
kde.fit(rs_array)

# If you want to evaluate the density at specific points:
x_d = np.linspace(0, max(rs)/10, 1000).reshape(-1, 1)
log_density = kde.score_samples(x_d)
pdf = np.exp(log_density)  # Convert log density to probability density



plt.fill_between(x_d.flatten(), pdf, alpha=0.6)
plt.title('Probability Density Function (PDF) - KDE')
plt.xlabel('$r$ values')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
# Create the plot with a filled area
plt.fill_between(x_d.flatten(), pdf, color='salmon', alpha=0.6)

# Add a line plot on the edges with a darker color
#plt.plot(x_d.flatten(), pdf, color='salmon', linewidth=1)  # Darker line

# Set plot titles and labels
#plt.title('Density')
#plt.xlabel('Radius (r)', fontsize=20)
#plt.ylabel('Density', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
# Adding grid for better readability
#plt.grid(True)
#plt.savefig(r'C:\Users\ss6365\Desktop\location_privacy-main\location_privacy-main\figure\density_plot.svg', format='svg')
# Show the plot
plt.show()

# %%
# Create the plot with a filled area
plt.fill_between(x_d.flatten(), pdf, color='salmon', alpha=0.6)

# Optional: add a line plot on the edges with a darker color
# plt.plot(x_d.flatten(), pdf, color='darkred', linewidth=1)  # Uncomment for a dark outline

# Set plot titles and labels
# plt.title('Density')  # Uncomment if title is needed
#plt.xlabel('Radius (r)', fontsize=20)
#plt.ylabel('Density', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=25)

# Adjust plot to ensure labels and titles are not cut off
plt.tight_layout()

# Save the plot as an SVG file with transparency
plt.savefig(r'C:\Users\ss6365\Desktop\location_privacy-main\location_privacy-main\figure\density_plot_2.svg', format='svg', transparent=True)

# Show the plot
plt.show()
