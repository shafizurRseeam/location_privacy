# %%
Laplace = [0.00012435, 0.00012184, 0.00012628, 0.00012752]
staircase = [0.00012224, 0.00012453,0.00012568, 0.00012527]
staircase_intermediate = [0.00046442,0.00036278, 0.00045037,  0.00043455]
laplace_delta = [0.00021473, 0.00019572, 0.00021386, 0.00020675]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
datasets = ['T-drive', 'Geolife', 'GPS T.', 'Collected']
Laplace = np.array([0.00006461, 0.0000628, 0.00006858, 0.00006209]) * 1e3
#laplace_delta = np.array([0.0001134, 0.00009956, 0.00009592, 0.00008120]) * 1e3
staircase = np.array([0.00008367, 0.00007712,0.00006437, 0.00006322]) * 1e3
staircase_intermediate = np.array([0.00027985,0.00041814, 0.00022846,  0.00025587]) * 1e3


# Colors and labels taken from the style of the line plot
colors = ['#1F77B4', '#FF7F0E', '#2CA02C']
labels = ['PLM', 'PSM', 'PSM-I']

# Set the positions and width for the bars
pos = np.arange(len(datasets))
bar_width = 0.25

# Plotting the bars with the new style
fig, ax = plt.subplots(figsize=(10, 6))  # Increase figure size to accommodate legend

for i, (data, color, label) in enumerate(zip([Laplace, staircase, staircase_intermediate], colors, labels)):
    ax.bar(pos + i * bar_width, data, bar_width, label=label, color=color)

# Adding labels and title
#ax.set_xlabel('Datasets', fontsize=28)
ax.set_ylabel('Runtime (ms)', fontsize=30)
#ax.set_title('Runtime Comparison')

# Positioning the x-ticks
ax.set_xticks(pos + bar_width)
ax.set_xticklabels(datasets, fontsize=30)

ax.set_xticklabels(datasets, fontsize=30, rotation=0)  # Rotate labels by 45 degrees

# Adding the legend with the modified style
# Reduce the handle length to decrease the space between the legend symbol and text
legend = ax.legend(fontsize=30, loc='upper center',  edgecolor='black', bbox_to_anchor=(0.74, 1),  shadow=True, ncol=2, handlelength=1, columnspacing=1, handletextpad=0.2)



frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width


# Setting the tick parameters
ax.tick_params(axis='both', which='major', labelsize=30)

# Adjust the layout to make room for the legend outside of the plot
#plt.subplots_adjust(top=0.75)
pathpng = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\miscellaneous_figures\\png\\Runtime_datasets.png'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')

pathsvg = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\miscellaneous_figures\\svg\\Runtime_datasets.svg'

plt.savefig(pathsvg, format='svg', bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# Sample data
datasets = ['AVD', 'Galaxy S22', 'MacBook']

Laplace = np.array([0.00016002, 0.00006209, 0.00002007]) * 1e3
#laplace_delta = np.array([0.00021360, 0.00008120, 0.00002576]) * 1e3

staircase = np.array([0.00016341,0.00006322, 0.00001966]) * 1e3
staircase_intermediate = np.array([0.00055342, 0.00025587, 0.00006454]) * 1e3

# Colors and labels taken from the style of the line plot
colors = ['#1F77B4', '#FF7F0E', '#2CA02C']
labels = ['PLM', 'PSM', 'PSM-I']

# Set the positions and width for the bars
pos = np.arange(len(datasets))
bar_width = 0.18

# Plotting the bars with the new style
fig, ax = plt.subplots(figsize=(10, 6))  # Increase figure size to accommodate legend

for i, (data, color, label) in enumerate(zip([Laplace, staircase, staircase_intermediate], colors, labels)):
    ax.bar(pos + i * bar_width, data, bar_width, label=label, color=color)

# Adding labels and title
#ax.set_xlabel('Datasets', fontsize=28)
ax.set_ylabel('Runtime (ms)', fontsize=30)
#ax.set_title('Runtime Comparison')

# Positioning the x-ticks
ax.set_xticks(pos + bar_width)
ax.set_xticklabels(datasets, fontsize=30, rotation=0)  # Rotate labels by 45 degrees

# Adding the legend with the modified style
# Reduce the handle length to decrease the space between the legend symbol and text
legend = ax.legend(fontsize=30, loc='upper center',  edgecolor='black', bbox_to_anchor=(0.74, 1),  shadow=True, ncol=2, handlelength=1, columnspacing=1, handletextpad=0.2)

frame = legend.get_frame()
frame.set_edgecolor('black')  # Set the border color
frame.set_linewidth(1)  # Set the border width

# Setting the tick parameters
ax.tick_params(axis='both', which='major', labelsize=30)

# Adjust the layout to make room for the legend outside of the plot
pathpng = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\miscellaneous_figures\\png\\Runtime_devices.png'
plt.savefig(pathpng, dpi=300, bbox_inches='tight')

pathsvg = 'C:\\Users\\ss6365\\Desktop\\location_privacy_final\\miscellaneous_figures\\svg\\Runtime_devices.svg'

plt.savefig(pathsvg, format='svg', bbox_inches='tight')

plt.show()
