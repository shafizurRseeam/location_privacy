# %%
import os
import shutil

def copy_matching_csv_files(source_directory_1, source_directory_2, destination_directory):
    # Ensure the destination directory exists
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)
    
    # Get a list of all CSV files in the first directory
    csv_files_in_first_dir = [f for f in os.listdir(source_directory_1) if f.endswith('.csv')]
    
    # Iterate over these CSV files and check if they exist in the second directory
    for csv_file in csv_files_in_first_dir:
        source_file_path = os.path.join(source_directory_2, csv_file)
        if os.path.exists(source_file_path):
            # File exists in the second directory, copy it to the destination directory
            destination_file_path = os.path.join(destination_directory, csv_file)
            shutil.copy(source_file_path, destination_file_path)
            print(f"Copied {csv_file} to {destination_directory}")

# Example usage
source_directory_1 = 'C:\\Users\\ss6365\\Desktop\\11111\\Geolife\\Dataset\\Utility_Geo'  # The first directory with CSV files to note
source_directory_2 = 'C:\\Users\\ss6365\\Desktop\\Geolife\\Geolife Trajectories 1.3\\Geolife Trajectories 1.3\AllCSV'  # The second directory to search for matching CSV files
destination_directory = 'C:\\Users\\ss6365\\Desktop\\Geolife\\test'  # The directory to copy the matching CSV files into

copy_matching_csv_files(source_directory_1, source_directory_2, destination_directory)
# Out:
# Copied 000_52.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 000_53.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 000_55.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 000_56.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 000_58.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 002_33.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_166.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_169.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_179.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_203.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_204.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_206.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_207.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_209.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_38.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_52.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_55.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_60.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 003_70.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_181.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_190.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_200.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_204.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_208.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_218.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_226.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_227.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_236.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_237.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_238.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_240.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_241.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_246.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_260.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_266.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_61.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_63.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 004_81.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 005_58.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 006_12.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 006_22.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 006_24.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 007_5.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 011_194.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 011_195.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 012_43.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 014_115.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 014_187.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 017_187.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 018_22.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 018_34.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 022_4.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 024_12.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 024_32.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 024_53.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 024_77.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 024_81.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 030_250.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 030_251.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 030_266.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 034_161.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_118.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_121.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_124.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_130.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_18.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_23.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_24.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_31.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_34.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_36.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_41.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_48.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_49.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_50.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_58.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_61.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 037_82.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 038_81.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 039_113.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 039_149.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 040_15.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_1.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_10.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_104.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_107.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_108.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_11.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_110.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_111.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_112.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_113.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_114.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_115.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_116.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_118.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_119.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_12.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_120.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_121.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_122.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_123.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_124.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_126.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_128.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_129.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_13.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_130.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_132.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_134.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_135.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_136.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_137.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_138.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_139.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_14.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_140.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_143.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_144.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_145.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_146.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_147.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_150.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_151.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_153.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_154.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_155.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_156.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_158.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_159.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_161.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_162.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_163.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_164.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_165.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_166.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_167.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_17.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_170.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_171.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_172.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_18.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_182.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_188.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_189.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_19.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_190.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_196.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_197.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_198.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_199.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_20.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_200.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_201.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_204.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_205.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_206.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_207.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_208.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_209.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_21.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_210.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_211.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_212.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_213.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_214.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_215.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_216.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_218.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_219.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_220.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_221.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_222.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_223.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_224.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_225.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_226.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_227.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_228.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_229.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_23.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_232.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_233.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_234.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_235.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_236.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_237.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_238.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_239.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_24.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_240.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_241.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_242.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_243.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_244.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_245.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_247.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_25.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_251.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_256.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_258.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_26.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_262.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_263.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_264.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_265.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_266.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_267.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_268.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_27.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_270.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_275.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_277.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_278.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_28.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_282.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_283.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_284.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_285.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_287.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_289.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_29.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_290.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_291.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_292.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_293.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_294.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_295.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_296.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_297.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_298.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_300.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_305.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_307.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_308.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_309.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_31.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_310.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_311.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_312.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_313.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_315.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_317.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_318.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_32.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_321.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_323.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_324.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_325.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_326.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_327.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_328.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_329.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_33.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_330.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_331.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_332.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_333.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_334.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_335.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_337.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_338.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_339.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_34.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_340.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_341.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_342.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_343.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_346.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_347.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_348.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_349.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_35.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_350.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_353.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_354.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_357.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_358.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_359.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_360.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_362.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_364.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_365.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_366.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_367.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_368.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_369.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_37.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_370.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_372.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_373.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_376.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_377.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_378.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_379.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_38.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_380.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_381.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_382.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_383.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_386.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_388.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_389.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_39.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_391.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_392.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_393.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_394.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_395.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_397.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_398.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_399.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_40.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_400.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_401.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_402.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_403.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_404.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_406.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_409.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_41.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_410.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_411.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_412.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_413.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_415.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_417.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_418.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_42.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_424.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_425.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_426.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_427.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_428.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_429.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_43.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_430.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_431.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_432.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_433.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_434.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_435.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_438.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_439.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_44.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_440.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_441.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_442.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_443.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_444.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_445.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_446.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_448.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_449.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_45.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_450.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_451.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_455.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_457.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_458.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_459.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_460.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_461.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_463.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_464.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_465.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_466.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_467.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_468.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_469.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_47.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_470.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_474.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_475.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_476.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_477.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_478.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_479.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_48.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_480.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_482.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_483.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_484.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_485.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_487.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_488.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_489.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_49.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_490.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_492.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_493.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_494.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_495.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_496.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_497.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_498.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_499.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_500.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_501.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_502.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_503.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_506.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_508.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_509.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_510.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_511.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_512.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_513.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_514.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_515.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_516.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_517.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_518.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_519.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_520.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_521.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_522.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_523.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_524.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_525.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_526.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_527.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_528.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_53.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_530.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_531.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_537.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_539.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_54.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_540.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_543.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_545.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_546.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_549.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_55.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_550.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_552.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_56.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_57.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_58.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_60.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_61.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_62.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_63.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_64.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_67.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_68.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_69.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_70.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_71.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_72.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_73.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_75.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_76.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_77.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_79.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_81.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_82.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_83.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_84.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_85.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_86.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_87.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_88.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_9.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_91.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_92.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_97.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 041_98.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_113.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_63.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_64.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_65.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_72.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_76.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_77.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_80.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_81.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_85.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_87.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 042_92.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 043_17.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 045_1.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 045_2.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 045_3.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 051_23.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 054_1.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 054_2.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 054_3.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 066_10.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 066_9.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 131_14.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 131_7.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 140_290.csv to C:\Users\ss6365\Desktop\Geolife\test
# Copied 142_116.csv to C:\Users\ss6365\Desktop\Geolife\test

# %%
import os
import pandas as pd

def calculate_sampling_rate(csv_file):
    df = pd.read_csv(csv_file)
    df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
    time_diffs = df['Time'].diff().dt.total_seconds().dropna()
    average_time_diff = time_diffs.mean()
    return 1 / average_time_diff if average_time_diff else 0

def mean_sampling_rate(directory):
    sampling_rates = []
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            try:
                sampling_rate = calculate_sampling_rate(file_path)
                sampling_rates.append(sampling_rate)
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    if sampling_rates:
        return sum(sampling_rates) / len(sampling_rates)
    else:
        return 0

# Example usage
directory = 'C:\\Users\\ss6365\\Desktop\\Geolife\\test'  # Replace this with the path to your directory
final_mean_sampling_rate = mean_sampling_rate(directory)
print(f"Final Mean Sampling Rate: {final_mean_sampling_rate} samples per second")
# Out:
# Final Mean Sampling Rate: 0.26339329821165364 samples per second

# %%
import os
import pandas as pd

def calculate_mean_time_difference(csv_file):
    df = pd.read_csv(csv_file)
    df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
    time_diffs = df['Time'].diff().dt.total_seconds().dropna()
    return time_diffs.mean()

def adjusted_mean_sampling_rate(directory):
    time_differences = []
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            try:
                mean_time_diff = calculate_mean_time_difference(file_path)
                if mean_time_diff > 0:
                    time_differences.append(mean_time_diff)
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    if time_differences:
        overall_mean_time_diff = sum(time_differences) / len(time_differences)
        # Convert the overall mean time difference to a sampling rate
        return 1 / overall_mean_time_diff
    else:
        return 0

# Replace 'path_to_your_directory' with the actual path to your directory
directory = 'C:\\Users\\ss6365\\Desktop\\Geolife\\test'
final_adjusted_mean_sampling_rate = adjusted_mean_sampling_rate(directory)
print(f"Adjusted Final Mean Sampling Rate: {final_adjusted_mean_sampling_rate} samples per second")
# Out:
# Adjusted Final Mean Sampling Rate: 0.16715903482998698 samples per second

# %%
import os
import pandas as pd

def calculate_file_sampling_rate(csv_file):
    df = pd.read_csv(csv_file)
    # Ensure 'Time' is in datetime format
    df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
    # Calculate total time span in seconds
    total_time_span = (df['Time'].iloc[-1] - df['Time'].iloc[0]).total_seconds()
    # Calculate sampling rate: total time span divided by the number of intervals (rows - 1)
    sampling_rate = (len(df) - 1) / total_time_span if total_time_span else 0
    return sampling_rate

def average_sampling_rate_across_files(directory):
    sampling_rates = []
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            try:
                sampling_rate = calculate_file_sampling_rate(file_path)
                sampling_rates.append(sampling_rate)
            except Exception as e:
                print(f"Error processing {filename}: {e}")
    # Calculate the average of the sampling rates
    return sum(sampling_rates) / len(sampling_rates) if sampling_rates else 0

# Example usage
directory = 'C:\\Users\\ss6365\\Desktop\\Geolife\\1'  # Replace this with the path to your directory
final_average_sampling_rate = average_sampling_rate_across_files(directory)
print(f"Final Average Sampling Rate: {final_average_sampling_rate} samples per second")
# Out:
# Final Average Sampling Rate: -0.08943308588728072 samples per second

# %%
import os
import pandas as pd

def calculate_average_logging_interval(csv_file):
    df = pd.read_csv(csv_file)
    df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S')
    if len(df) > 1:  # Ensure there are at least two points to calculate a time span
        total_time_span = (df['Time'].iloc[-1] - df['Time'].iloc[0]).total_seconds()
        average_logging_interval = total_time_span / (len(df) - 1)
    else:
        average_logging_interval = 0  # Cannot calculate an interval with fewer than 2 data points
    return average_logging_interval

def mean_logging_interval(directory):
    logging_intervals = []
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            average_interval = calculate_average_logging_interval(file_path)
            if average_interval:  # Only consider non-zero intervals
                logging_intervals.append(average_interval)
    # Compute the mean of the logging intervals
    mean_interval = sum(logging_intervals) / len(logging_intervals) if logging_intervals else 0
    return mean_interval

# Example usage
directory = 'C:\\Users\\ss6365\\Desktop\\Geolife\\1'  # Replace this with the path to your directory
final_mean_logging_interval = mean_logging_interval(directory)
print(f"Final Mean Logging Interval across all files: {final_mean_logging_interval} seconds")
# Out:
# Final Mean Logging Interval across all files: -11.181544168792025 seconds
